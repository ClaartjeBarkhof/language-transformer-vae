# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
import pickle
import pandas as pd

# %% [markdown]
# # Extract Pareto dicts from last checkpoint that was saved

# %%
from utils_analysis import read_overview_csv

df = read_overview_csv()
df
# Out:
# Saving overview in /home/cbarkhof/code-thesis/NewsVAE/final-analysis/run_overview.csv
#                                              run_name  \
# 0   2021-05-24-PTB | CYC-FB-0.5 | matrix-memory-ru...
# 1          2021-05-21-PTB | VAE | memory-run-05:50:37
# 2   2021-05-21-PTB | VAE | memory | DROP 40-run-05...
# 3   2021-05-21-PTB | VAE | memory-embeddings-run-0...
# 4   2021-05-21-PTB | VAE | memory-embeddings | DRO...
# 5   2021-05-25-PTB | MDR-0.5 | matrix-memory-run-0...
# 6   2021-05-22-PTB | CYC-FB-0.5 | memory-run-02:03:27
# 7   2021-05-22-PTB | CYC-FB-0.5 | memory | DROP 40...
# 8   2021-05-22-PTB | CYC-FB-0.5 | memory-embedding...
# 9   2021-05-22-PTB | CYC-FB-0.5 | memory-embedding...
# 10  2021-05-24-PTB | CYC-FB-0.5 | matrix-memory | ...
# 11     2021-05-22-PTB | MDR-0.5 | memory-run-14:01:39
# 12  2021-05-22-PTB | MDR-0.5 | memory | DROP 40-ru...
# 13  2021-05-22-PTB | MDR-0.5 | memory-embeddings-r...
# 14  2021-05-22-PTB | MDR-0.5 | memory-embeddings |...
# ...

# %% [markdown]
# # Plot pareto efficient stats

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from utils_analysis import plot_pareto_stats, get_pareto_efficient_dict

# %%
# Out:
#    efficient_epochs  iw_ll_mean  iw_ll_x_gen_mean     -D_ks  \
# 0                 3  -93.664501        -68.858094 -0.152381
#
#    iw_ll_mean_minmax_norm  iw_ll_x_gen_mean_minmax_norm  -D_ks_minmax_norm  \
# 0                     1.0                           1.0                1.0
#
#    combined_weighted_score
# 0                      8.0
#     efficient_epochs  iw_ll_mean  iw_ll_x_gen_mean     -D_ks  \
# 3                  6  -87.236853        -79.159587 -0.199405
# 6                  9  -87.954456        -78.293705 -0.334821
# 7                 10  -89.066286        -73.588673 -0.383929
# 5                  8  -89.739929        -73.404544 -0.319940
# 10                15  -90.735885        -68.087694 -0.520833
# 8                 12  -90.619700        -70.293166 -0.433036
# 4                  7  -89.326990        -77.847782 -0.257440
# 0                  2  -88.114716        -86.828971 -0.029762
# 12                17  -91.867651        -65.752281 -0.562500
# ...
