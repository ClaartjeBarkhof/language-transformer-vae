# %% [markdown]
# # Imports

# %%
import sys; sys.path.append("../..")
from EncoderDecoderShareVAE import EncoderDecoderShareVAE
import NewsVAEArguments
import torch
from transformers.generation_utils import top_k_top_p_filtering
from NewsData import NewsData
import numpy as np
import copy
import torch.nn.functional as F
from trainNewsVAE import load_from_checkpoint
from utils import transfer_batch_to_device
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# from pytorch_lightning import seed_everything; seed_everything(0)

# Check if on server
if torch.cuda.is_available():
    print("Using GPU :-)...")
    device = "cuda"
else:
    print("Warning: using CPU!")
    device = "cpu"
    
# Overwrite some arguments
args = NewsVAEArguments.preprare_parser(jupyter=True, print_settings=False)
args.ddp = False
args.n_gpus = 1

import multiprocessing; print("Number of CPU cores: {}".format(multiprocessing.cpu_count()))
# Out:
# Using GPU :-)...
# Number of CPU cores: 12

# %% [markdown]
# # Get some validation data to experiment with

# %%
# Get data
data = NewsData(args.dataset_name, args.tokenizer_name,
                batch_size=args.batch_size, num_workers=args.num_workers,
                pin_memory=(device=="cuda"), debug=args.debug_data,
                debug_data_len=args.debug_data_len, max_seq_len=args.max_seq_len, device=device)

# %% [markdown]
# # Loading pre-trained models (Beta-VAE and MMD-VAE checkpoint)

# %%
# Get model architecture
VAE_model = EncoderDecoderShareVAE(args, args.base_checkpoint_name, do_tie_weights=args.do_tie_weights).to(device)

# # Load weights
beta_vae_path = "/home/cbarkhof/code-thesis/NewsVAE/Runs/18NOV-BETA-VAE-run-2020-11-18-12:36:55/checkpoint-best.pth"
mmd_vae_path = "/home/cbarkhof/code-thesis/NewsVAE/Runs/18NOV-MMD-VAE-run-2020-11-18-12:36:55/checkpoint-best.pth"

# Need to make a deepcopy otherwise the weights are assigned to the original VAE_model which leads to confusing results :O
_, _, beta_vae, _, _, _, _ = load_from_checkpoint(copy.deepcopy(VAE_model), path=beta_vae_path)
_, _, mmd_vae, _, _, _, _ = load_from_checkpoint(copy.deepcopy(VAE_model), path=mmd_vae_path)

beta_vae.eval(); mmd_vae.eval(); VAE_model.eval();
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VAE_Decoder_RobertaForCausalLM were not initialized from the model checkpoint at roberta-base and are newly initialized: ['lm_head.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <class 'VAE_Decoder_Roberta.VAE_Decoder_RobertaModel'> and <class 'transformers.modeling_roberta.RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Loading VAE_model, optimizer and scheduler from /home/cbarkhof/code-thesis/NewsVAE/Runs/18NOV-BETA-VAE-run-2020-11-18-12:36:55/checkpoint-best.pth
# first removing module string from checkpoint
# Checkpoint global_step: best, epoch: 18, best_valid_loss: 3.141055178642273
# Loading VAE_model, optimizer and scheduler from /home/cbarkhof/code-thesis/NewsVAE/Runs/18NOV-MMD-VAE-run-2020-11-18-12:36:55/checkpoint-best.pth
# first removing module string from checkpoint
# Checkpoint global_step: best, epoch: 32, best_valid_loss: 2.2885116815567015

# %%
def batch_decode(batch_of_samples, tokenizer):    
    return [tokenizer.decode(a.tolist()) for a in batch_of_samples]

def auto_regressive_decode(model, latent_z, tokenizer, args, max_seq_len=32, nucleus_sampling=False, temperature=1.0, top_k=0, top_p=0.9):
    batch_size = latent_z.shape[0]

    # Add <s> and </s>
    generated_so_far = torch.tensor([[data.tokenizer.bos_token_id, data.tokenizer.eos_token_id] for _ in range(batch_size)])
    generated_so_far = generated_so_far.cuda(0)

    for i in range(max_seq_len):        
        # Forward the decoder
        decoder_outs = model.decoder(input_ids=generated_so_far, attention_mask=None,
                                    latent_z=latent_z, labels=None,
                                    add_latent_via_embeddings=args.add_latent_via_embeddings,
                                    add_latent_via_memory=args.add_latent_via_memory,
                                    return_cross_entropy=False, return_predictions=True,
                                    return_exact_match_acc=False)

        if nucleus_sampling:
            # The forward of the decoder already cuts of the prediction for the last token
            logits = decoder_outs["logits"][:, -1, :]

            # Temperature (higher temperature => more likely to sample low probability tokens)
            if temperature != 1.0:
                scores = scores / temperature

            # Top-p/top-k filtering
            next_token_logscores = top_k_top_p_filtering(logits, top_k=top_k, top_p=top_p)

            # Sample
            probs = F.softmax(next_token_logscores, dim=-1)
            new_preds = torch.multinomial(probs, num_samples=1).squeeze(1)
        else:
            new_preds = decoder_outs['predictions'][:, -1] # argmax predictions

        generated_so_far = torch.cat((generated_so_far[:, :-1], new_preds.unsqueeze(1), generated_so_far[:, -1].unsqueeze(1)), dim=1)
    return generated_so_far

def encode(model, input_batch, deterministic=False):
    encoder_outs = model.encoder(input_ids=input_batch['input_ids'], attention_mask=input_batch['attention_mask'])
    latent_z, _, _ = model.connect_encoder_decoder(encoder_outs.pooler_output, deterministic=deterministic)
    
    return latent_z

def encode_auto_regressive_decode(model, input_batch, tokenizer, args, max_seq_len=64, nucleus_sampling=True):
    with torch.no_grad():
        latent_z = encode(model, input_batch)
        generated = auto_regressive_decode(model, latent_z, tokenizer, args, max_seq_len=max_seq_len, nucleus_sampling=nucleus_sampling)
        generated_text = batch_decode(generated, tokenizer)
        
        return generated_text

# %% [markdown]
# # Reconstruct text with different trained models and different sampling

# %%
results = {'original': [],
           'argmax': {
               'beta-VAE': [], 
               'MMD-VAE': [], 
               'untrained-VAE': []
           }, 
           'nucleus_sampling': {
               'beta-VAE': [], 
               'MMD-VAE': [], 
               'untrained-VAE': []
           }
          }

max_batches = 5
for batch_i, input_batch in enumerate(data.val_dataloader(shuffle=True)):
    
    input_batch = transfer_batch_to_device(input_batch, 0)
    original_text = batch_decode(input_batch['input_ids'], data.tokenizer)
    results['original'].extend(original_text)
    
    for sampling, sampling_mode in zip([True, False], ['nucleus_sampling', 'argmax']):
        for model, model_name in zip([mmd_vae, beta_vae, VAE_model], ['MMD-VAE', 'beta-VAE', 'untrained-VAE']):
            generated_text = encode_auto_regressive_decode(model, input_batch, data.tokenizer, 
                                                           args, max_seq_len=64, nucleus_sampling=sampling)
            results[sampling_mode][model_name].extend(generated_text)

    if batch_i + 1 == max_batches: break
# Out:
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)

# %%
for i in range(len(results['original'])):
    print("*"*40)
    print("SAMPLE", i)
    print("*"*40)
    print("\n-> Original text:\n", results['original'][i], '\n')
    print("-"*40)
    
    for sampling, sampling_mode in zip([True, False], ['nucleus_sampling', 'argmax']):
        print("\n {} -> Untrained VAE:\n".format(sampling_mode.upper()), results[sampling_mode]['untrained-VAE'][i])
        print("\n {} -> Beta VAE:\n".format(sampling_mode.upper()), results[sampling_mode]['beta-VAE'][i])
        print("\n {} -> MMD VAE:\n".format(sampling_mode.upper()), results[sampling_mode]['MMD-VAE'][i], '\n')
# Out:
# ****************************************
# SAMPLE 0
# ****************************************
#
# -> Original text:
#  <s>(CNN)Seven college-age people, some who came to Panama City Beach, Florida, for spring break, were wounded in a late-night shooting, the Bay County Sheriff's Office said in a press release. Officers met "complete chaos" when they tried to find out what happened not long after midnight</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s></s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>A new wave of people visiting the Oklahoma state beach after a deadly shooting spree entered the third neighborhood where the gunman -- an 18-year-old suspect -- lived, a report from the state Justice Department said Wednesday. About 60 people checked into a condo at the 6 Seasons Resort and Casino in northeast Oklahoma City,</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN)Thirty-five college students, some of them first-time graduates, came to Panama City Beach, Florida, for a "gay-filled" mass shooting in late May that happened, police said. Police officers were called to the harbor in a break-up when they didn't find any help</s></s></s>
#
#
#  ARGMAX -> Untrained VAE:
#  <s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>.</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
#
#  ARGMAX -> Beta VAE:
#  <s>(CNN) -- Some students at a Florida high school were upset after a gunman opened fire at a campus on Monday, killing six people and injuring dozens, authorities said. Some students and faculty were staying in a nearby hotel, where they were staying to avoid the possibility of a gunman returning to the school, said</s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>(CNN)Seven-year-old Bay Area College students, some of them college-age, came to a Florida beach party, police said, when they tried to escape in the chaotic aftermath of a shooting in late May. "People were OK for some time," Mackenzie White told reporters who came to</s></s></s>
#
# ****************************************
# SAMPLE 1
# ****************************************
#
# -> Original text:
#  <s>(CNN)In 2007 I had my ovaries and fallopian tubes removed to prevent my getting ovarian cancer. It was a surgery of the kind that Angelina Jolie recently underwent, as she revealed Tuesday in a New York Times op-ed.  Two years ago, Jolie divulged that she'd</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s></s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>By. Katie Davies. Last month Vogue in Washington famously decided to withdraw a comment on the infamous Backstreet. In February 2007, Zoe Hoffman had a cosmetic operation to correct the silicone bruins on her nose, and will now wear out her monthly Vanity Fair policy on her lipstick. It's a condition that</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN) -- I had ovaries and fallen ovary in 2005 to prevent my from having a baby. In 2007, it was her recently revealed surgery to remove those ovaries, my ex-fiance Michelle Covalt told CNN. "I got that thing a couple of years ago when I was op</s></s></s>
#
#
#  ARGMAX -> Untrained VAE:
#  <s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s></s>
#
#  ARGMAX -> Beta VAE:
#  <s>(CNN)In 2007, Angelina Jolie revealed that she had undergone a double mastectomy. The news was confirmed by her doctor, and Jolie's doctor confirmed that she had undergone a double mastectomy in 2007. "I've been in the same place since I was a teenager, and I've</s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>(CNN)In 2007 and 2008, I had ovaries removed from my ovaries to prevent ovarian cancer. It was a fall of the good fortune that my surgeon recently revealed that she'd had one of them surgically, Angelina Jolie told CNN in a recent interview. Jolie taunted the surgery</s></s></s>
#
# ****************************************
# SAMPLE 2
# ****************************************
#
# -> Original text:
#  <s>(CNN)As a well-traveled photographer, Pieter ten Hoopen is no stranger to refugee camps. But he never experienced any like the Mayo camp, which is outside the Sudanese capital of Khartoum. Ten Hoopen was at the camp to photograph a new medical clinic for Emergency,</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s></s> << << Garfield Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown</s></s></s></s></s></s></s> Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown Brown</s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>(CNN)While the five-month operation for William Haberman's six-month study into the Tibetan spiritual belief system wasn't a rush for anyone, it proved the ideal place to be. A refugee camps in Tibet have suffered a host of trouble, from polio to illegal entry into the troubled territory, with</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN
s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>(CNN)There was a time when Chuck Norris lived near to Death Row, but nobody called him a name. Chuck Norris has changed his name and has to count twice. Chuck Norris crosses the street without being cross-eyed. But there was always Halloween. The annual Chuck Norris Celebration celebrated a 150-year</s></s></s>
#
# ****************************************
# SAMPLE 8
# ****************************************
#
# -> Original text:
#  <s>(CNN)Two more American aid workers who had high-risk exposure to Ebola in Sierra Leone arrived back in the United States on Monday for monitoring. Neither is sick or known to be infected with the disease. Eight of their colleagues have already been flown back to the United States, where health authorities are watching them</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>(CNN) -- At least two international astronauts missing since the United States launched the manned space mission to be with the International Space Station are being sent to other countries. Five foreign children infected with Ebola, in Japan, three Americans and a fourth in Liberia were flown to Argentina on Thursday. All five remained well enough</s>The</s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN)Two American aid workers who had less than eight hours on high alert in Sierra Leone returned to the United States to watch for Ebola. One of the two men monitoring health conditions in Sierra Leone is now infected with the virus, and they have not been expected to be back in hospital. Security officials are</s></s></s>
#
#
#  ARGMAX -> Untrained VAE:
#  <s><s><s><s></s> in in in in in in in in in in the in in in in in in in in the unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit unit</s>
#
#  ARGMAX -> Beta VAE:
#  <s>(CNN)Two Americans who were traveling to Afghanistan to support their Afghan counterparts in Afghanistan have been found dead in their hotel room, the U.S. State Department said Thursday. Two Americans who were traveling with their Afghan counterparts were found dead in their hotel room Thursday. The two Americans, who were traveling with</s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>(CNN)Two American aid workers who had high-grade Ebola in Sierra Leone returned to the United States sickened for another week. No one else on the monitoring team is yet to be exposed to the virus, and they have been monitored closely in neighboring countries. Officials with the United States are waiting for news</s></s></s>
#
# ****************************************
# SAMPLE 9
# ****************************************
#
# -> Original text:
#  <s>(CNN)Nearly 70 years ago, comic strip detective Dick Tracy showed off his first two-way wrist radio, inspiring baby boomers to babble into their knuckles in pursuit of bad guys like Pruneface and the Mole.  The gadget was updated to a TV phone in 1964, heralding</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s><s><s></s></s></s></s></s>'t essential cookies cooking</s>....</s></s></s>.,</s></s></s></s></s></s></s></s></s></s></s>...</s></s></s></s></s>...food</s>;</s> store</s> and�</s></s></s></s>,</s>,.our</s></s></s>.</s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>(CNN) -- The jolted American Girl -- a levity hero which peaked on television shows as "Playtime and Show Me a Car" and "Brotherly Love" on the daily newsstands -- got its first charge on America's 47th birthday in 1888. When National Geographic unveiled its version</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN)About two decades ago, comic book pioneer Dick Tracy punched his puffed-up toy phone to show off its new gadgets in shocking blunders, heralding the ‘wave of 92-year-old Motorola device to be copied. Tracey lived in prison in 1970 and came across a word</s></s></s>
#
#
#  ARGMAX -> Untrained VAE:
#  <s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s></s>
#
#  ARGMAX -> Beta VAE:
#  <s>(CNN) -- A decade ago, a new video game called "The Spinal Tap" was released with a splash of new technology that would make it look like a new era of video games. Bruce Springsteen's "Spinal Tap" was released in 1999, and the first-person shooter to hit</s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>(CNN)Nearly 70 years ago, radio tycoon Dick Tracy showed off his first gadget gadget, Chubby Checkers, to boxer-like vibranes in the vein of Spider-Man and inspiring young boys to jump in their underwear. The pair were called a Second World War hammer to tackle mutant mutant</s></s></s>
#
# ****************************************
# SAMPLE 10
# ****************************************
#
# -> Original text:
#  <s>(CNN)When Oakland Raiders NFL running back Maurice Jones-Drew retired recently at just 29 years old, he said his life had been focused on football for 24 years and he needed a change. It's no wonder he wanted out. He has been playing football since he was 5 years old. Sound too</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>(CNN)It has been 30 years since Jerry Daly was a player who lived in Oakland. His participation in the light soccer game in Oakland was usually reserved for the athletes on an athletic level, but a bit of work has kept Daly on the field until he moved to downtown Oakland. Daly was an electrician</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN
s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s></s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>Remember, the Israeli government "never said to stop" Palestinian president Mahmoud Abbas. But he's on the opposite side of the truth, which means Israel is never going to try to stop Palestinian leaders. During a speech at an Israeli Military Commission meeting Thursday night, Abbas told a large crowd of cheering audience members,</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>Washington (CNN)Two-term President Barack Obama says he still doesn't take it personally with the Israelis. It doesn't matter when the White House says he is never going to use his two-week solution at a Jerusalem prime minister's hands. "We tried to make him understand that we would now stop</s></s></s>
#
#
#  ARGMAX -> Untrained VAE:
#  <s></s></s></s></s></s></s></s></s>
#
#  ARGMAX -> Beta VAE:
#  <s>(CNN) -- The White House says it doesn't want to talk about the border crisis anymore. But the president says he doesn't want to talk about the "tensions" between the United States and Mexico. In a long-awaited interview with Fox News, President Barack Obama said he doesn't want to</s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>Washington (CNN)It doesn't take long for two Israeli Prime Minister Benjamin Netanyahu to now say he doesn't like the United States. The White House says he still has a "never-tending" position with Netanyahu when he takes his words at his Cabinet. It was refused at the time. "When</s></s></s>
#
# ****************************************
# SAMPLE 14
# ****************************************
#
# -> Original text:
#  <s>(CNN)If you haven't yet been asked by friends or co-workers to Meerkat, chances are you will soon. The livestreaming app was the "SXSW sweetheart" this year, despite having only launched on February 27. It's been adding users rapidly ever since -- even Jimmy</s>
#
# ----------------------------------------
#
#  NUCLEUS_SAMPLING -> Untrained VAE:
#  <s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s><s></s>
#
#  NUCLEUS_SAMPLING -> Beta VAE:
#  <s>(CNN) -- Facebook has just announced it will be hosting a worldwide worldwide live social media event when/then/as/when Facebook is re-launched. Those who have been following the social network's social media base for months have been hoping their enthusiasm will reignite, even if it's the first</s></s></s>
#
#  NUCLEUS_SAMPLING -> MMD VAE:
#  <s>(CNN)If you haven't been meeting friends or friends on Facebook yet, the "X Factor" was already an instant hit. Soursay) will soon be offering users to bestow with Meerkat fans by the chance next June. It hasn't been fast yet, but it was wildly popular</s></s></s>
#
#
#  ARGMAX -> Untrained VAE:
#  <s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
#
#  ARGMAX -> Beta VAE:
#  <s>(CNN) -- Facebook is already a popular social network for people who want to chat to each other, but it's now becoming a reality for millions of people. According to a new report from the Pew Internet & American Life Project, Facebook users are now using the site to chat with friends, including those who</s></s></s>
#
#  ARGMAX -> MMD VAE:
#  <s>(CNN)If you haven't been meeting friends on Facebook or Twitter yet, chances are you'd be forgiven. The X-Factor co-creator has been quietly joining the app by now, promising "swallow me" months after it was first launched. It's only SOY -- and wow -- huge</s></s></s>

# %% [markdown]
# # Sampling

# %%
def sample_from_prior(latent_size=768, n_samples=8):
    loc = torch.zeros(latent_size, device='cuda:0')
    scale = torch.ones(latent_size, device='cuda:0')
    prior_dist = torch.distributions.normal.Normal(loc, scale)
    samples = prior_dist.sample((n_samples,))
    return samples
    
def sample_text(model, tokenizer, args, n_samples=8, max_seq_len=64, nucleus_sampling=True):
    with torch.no_grad():
        latent_z = sample_from_prior(model.latent_size, n_samples=n_samples)
        generated = auto_regressive_decode(model, latent_z, tokenizer, args, max_seq_len=max_seq_len, nucleus_sampling=nucleus_sampling)
        generated_text = batch_decode(generated, tokenizer)
        return generated_text

# %%
for model, name in zip([mmd_vae, beta_vae], ['MMD-VAE', 'Beta-VAE']):
    print('Samples from:', name)
    gen_text = sample_text(model, data.tokenizer, args, n_samples=20, max_seq_len=64, nucleus_sampling=True)
    for i, t in enumerate(gen_text):
        print(i)
        print(t)
        print()
    print("-"*30)
# Out:
# Samples from: MMD-VAE
# 0
# <s> they of ofilesos and and ofigisippers and and smugglers. ofus.s..ania areates on on with ofures and on Tuesday ofs ofis ofs ofs and peoples ofon ofis ofates on Tuesday on Monday.. and ofims forors. but</s></s></s>
#
# 1
# <s>travel ��……!”(s , –, a!…’,…!!,’…,!,, again!”!!!….,’.!, – –,, we’t ,,’..</s></s></s>
#
# 2
# <s> Augustger Meues,, Japanese 72ues, Japan, Mainets, Lockheedgers Lockheed, 80, takesues as Harbor, 7480,,uesuesues asuesues,,54, followsuesuesues, continuesuesuesuesues,72uesues,80, continuesuesuesuesuesuesues</s>
#
# 3
# <s>By Mark Mark Mark In. Mark Mark In Policy Policy Service. Modern Strategy For For Growth. Mark Mark Mark.. Mark. 2004:.. 10 2013:. 2014 2014 2012. 02:.:. 14 House.:. October.. 12: Inative: Tom Speaker to:. of</s></s></s>
#
# 4
# <s>Parisinrescresty staff,fcty)tyNewsNews)Newsroom)...tyxcom,...News...:];... Forces(tytyty;;...ises:;;:,:;;.?;;,:;,,:,,;</s></s></s>
#
# 5
# <s>- profession orvan orHer or or Rafael or or or or or or or of or (/re) of of of of a of of of or of of of of a of of of of of a of of of its of of of a of of during a of of of of of at air</s></s></s>
#
# 6
# <s>By Maker Ways. Party. Forward Forward Way Officers Council We Ways Self. Forward Forward Forward inBy National Open Forward Ways Out Years Order Citizens Maker Public Citizen Minister colleagues Forward Senior OfficersWay Citizen Citizen At CitizenForward By.After Star WaysOfficials wayman ButmanmakersERS hadin Ministers councillors in in were but</s>ton</s>
#
# 7
# <s> Scandinav Los Kabul -- The Norwegian Afghan Bombol Afghanistanic Theigon Afghanistan can't can Afghanal'si can...  onal can, atseol, TheThetonly thely canoeschlemian's's no theton'll'shashet'd has has in have have will haveTheem</s></s></s>
#
# 8
# <s> London?* —... names,??.…:?:,:.:.?.?..?:?:.,???.,,,,:.,:,...:,,,,.,?,,..,,,:</s></s></s>
#
# 9
# <s> Freedom Tuesday out going out in middle in.On in her. CNN out. As in her of as came in an of. In. In a of Thursday of in a Wednesday,, in part, of Wednesday,, of,,, in Friday, and, a Wednesday,, a, in went</s></s></s>
#
# 10
# <s>Call he It He that may it a directed would a married routine he he which the real reality reality. He certainly that took a den ideal.. John was Toronto has that a mad lifestyle. The He Toronto reality. has a complex reality standards. That He. That has a perfect lifestyle skills. The Kevin</s></s></s>
#
# 11
# <s>48 President of of for.-// or- South. or to, of you to for to to to those of the move your from for of these to the images and of a from this of a toward coming to to a kind of for for his from of a a home and said of a recent</s></s></s>
#
# 12
# <s> Brendan of of one of one of one of of an no on of of one of of one one one of of to of one of of the the of of one, one- one one of an of one of one of in, one one of of one of paper, one one one, one of</s></s></s></s>
#
# 13
# <s>Â guy worldwide Surf leader known to-for known leader known taking before out that Jacob Alex Clifford Rogers forward-FOR Champion-to-Don-to-F Dale Roc-to going before to.-l known builder Jacob/to. T. LAPD.. Los. Born to before. May. $</s></s></s>
#
# 8
# <s>(CNN) -- The soggy world of alcohol has been in trouble. Maria's spirits continue to soar for the Maldives, as the nation recovers from the devastating events that affected its dancing festival. Some say this was due to Diana Nyid's recovery from malaria. The British-based bout, known</s></s></s>
#
# 9
# <s>By. Daily Mail Reporter and Associated Press. PUBLISHED:. 10:56 EST, 26 February 2014. |. UPDATED:. 10:56 EST, 26 February 2014. Is the federal government denying many of the Olympic gold medalists in the Jack White Pass massacre on the run after he</s> Federal</s>
#
# 10
# <s>(CNN) -- It could all be about the release of a statement from the president of the United States. In August 2013, the president of Canada appealed for a unity solution after Hurricane Irene wreaked havoc across the Atlantic and into the Middle East. "I hope that we can then determine an acceptable way</s></s></s>
#
# 11
# <s>Beijing (CNN) -- A giant butler who used his body to stunt New York City's Chinatown just to stir up debate is being locked in a prolonged sentence after using a ceremonial sword. Protesters tried to keep President Barack Obama and other top officials from attending the annual Fourth of July holiday on Tuesday night by</s></s></s>
#
# 12
# <s>By. Steve Nolan. PUBLISHED:. 16:54 EST, 24 October 2013. |. UPDATED:. 04:13 EST, 25 October 2013. It has been claimed that a suicide bomber has managed to escape a rock at a Russian university. The body of the German student, based</s></s></s>
#
# 13
# <s>By. Matt Chorley. Updated:. 08:22 EST, 3 January 2012. They have won a winning few. The German Chancellor Angela Merkel is pictured with one of her staff members at an event in Hauschladgart. Her words have shocked the world today. Pelosi, 47, is</s></s></s>
#
# 14
# <s>By. James Rush. PUBLISHED:. 18:04 EST, 17 November 2013. |. UPDATED:. 19:49 EST, 17 November 2013. The total number of casualties has shot up to 15 after President Barack Obama’s visit to the southern Indian region of Bhopal</s>.</s>
#
# 15
# <s>Moscow (CNN) -- The Pentagon ordered an end to a number of hounded Secret Service documents related to an event at the White House that the Obama administration plans to discuss with members of Congress in coming months. The report -- the four-page "homekeeping" manual of the Department of Homeland Security's Policy</s></s></s>
#
# 16
# <s>LONDON, England (CNN) -- In an optically controlled environment, the older brother of a California volcano expert told CNN Sunday that he has adopted the human's rights in developing countries despite a lack of transparency about public safety. Italian climber Milan Manfredo Scarpari says he did not so much</s></s></s>
#
# 17
# <s>By. Daily Mail Reporter. PUBLISHED:. 06:42 EST, 7 January 2013. |. UPDATED:. 04:31 EST, 8 January 2013. Pediatric surgery worker Mike Deveaux thought a disease had gone down by shooting a young woman a mere three hours later. John</s></s></s>
#
# 18
# <s>Ridicopaosa, Arizona (CNN) -- Michael Bayce, who had been a medical alert for an ankle injury, is "completely over, absolutely mortified" and should be released into rehab, the media and the medical examiner in both cases said Saturday. The preliminary report was made just before noon</s></s></s>
#
# 19
# <s>NOURIA, South Africa (CNN) -- For a group of midsized small boats, the passage of sovereignty is an impoike. Sama Ana, a Cuban-American logger, faces the threat of earthquake and tsunami because of the safety of the vessel. Then the endangered San Juan River is</s></s></s>
#
# ------------------------------

# %%
n_samples = 1000
batch_size = 10

prior_samples = sample_from_prior(latent_size=768, n_samples=n_samples)

encoded_samples_beta = []
encoded_samples_mmd = []

with torch.no_grad():
    assert n_samples % batch_size == 0, "n_samples must be exactly divisible by the batch size!"
    max_batches = int(n_samples / batch_size)
    print(max_batches)
    for batch_i, input_batch in enumerate(data.val_dataloader(shuffle=True, batch_size=batch_size)):
        if batch_i % 10 == 0: print("Batch {:2d}/{}".format(batch_i, max_batches), end='\r')

        input_batch = transfer_batch_to_device(input_batch, 0)
        encoded_samples_beta.append(encode(beta_vae, input_batch, deterministic=False))
        encoded_samples_mmd.append(encode(mmd_vae, input_batch, deterministic=False))

        if batch_i + 1 == max_batches: break
        
encoded_samples_beta = torch.cat(encoded_samples_beta)
encoded_samples_mmd = torch.cat(encoded_samples_mmd)

print(prior_samples.shape, encoded_samples_beta.shape, encoded_samples_mmd.shape)
# Out:
# 100
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# torch.Size([1000, 768]) torch.Size([1000, 768]) torch.Size([1000, 768])

# %%
all_samples = torch.cat((prior_samples, encoded_samples_beta, encoded_samples_mmd))
all_samples_pca = PCA(n_components=50).fit_transform(all_samples.cpu().numpy())
all_samples_tsne_2dim = TSNE(n_components=2, n_iter=500, perplexity=20).fit_transform(all_samples_pca)

# %%
plt.scatter(all_samples_tsne_2dim[:1000, 0], all_samples_tsne_2dim[:1000, 1], label='Prior', alpha=0.3, color='green')
plt.scatter(all_samples_tsne_2dim[1000:2000, 0], all_samples_tsne_2dim[1000:2000, 1], label='Encoded Beta-VAE', alpha=0.3, color='blue')
plt.scatter(all_samples_tsne_2dim[2000:, 0], all_samples_tsne_2dim[2000:, 1], label='Encoded MMD-VAE', alpha=0.3, color='pink')
plt.legend()
plt.show()

# %% [markdown]
# # Interpolation

# %%
import pandas as pd

def interpolate(z1, z2, steps=10):
    z_step = (z2 - z1) / (steps-1)
    
    interpolated_zs = [z1 + (i * z_step) for i in range(steps)]
    interpolated_zs = torch.stack(interpolated_zs)
    
    return interpolated_zs

for batch_i, input_batch in enumerate(data.val_dataloader(shuffle=True, batch_size=2)):
    
    print("*"*80)
    print("\nINTERPOLATION {}".format(batch_i))
    print("-"*80)

    result = {}
    
    with torch.no_grad():
        input_batch = transfer_batch_to_device(input_batch, 0)
        original_texts = batch_decode(input_batch['input_ids'], data.tokenizer)
        
        print("*"*50)
        print("** SOURCE SENTENCE:")
        print("*"*50)
        print(original_texts[0])
        
        result = {}
        
        for (model, model_name) in zip([mmd_vae, beta_vae], ["mmd_vae", "beta_vae"]):
            latent_z = encode(model, input_batch, deterministic=False)
                
            zs = interpolate(latent_z[0, :], latent_z[1, :])

            generated = auto_regressive_decode(model, zs, data.tokenizer, args, max_seq_len=64, nucleus_sampling=False)
            generated_text = batch_decode(generated, data.tokenizer)

            result[model_name] = generated_text
            
        for i in range(len(generated_text)):
            print("Step {}\n".format(i))
            print("-> MMD-VAE:\t", result['mmd_vae'][i])
            print("-> Beta-VAE:\t", result['beta_vae'][i])
            print('-'*80)
        
        print("*"*50)
        print("** TARGET SENTENCE:")
        print("*"*50)
        print(original_texts[1])

    break
# Out:
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# ********************************************************************************
#
# INTERPOLATION 0
# --------------------------------------------------------------------------------
# **************************************************
# ** SOURCE SENTENCE:
# **************************************************
# <s>Maui, Hawaii (CNN)When she was just 4 years old, Chelsea Elliott went blind in her left eye. Then, two years later, she lost hearing in her right ear. Now 24, Elliott might have been spared years of struggle if her rare eye condition -- known as Coats disease --</s>
# Step 0
#
# -> MMD-VAE:	 <s>When she was 4 years old, she lost her left eye in Hawaii. Then, in 2002, Clara Coghlan was 14 years old. Now, her eyesight could never be matched by her rare hearing loss -- when she went blind in 2009. Coghlan, 24, may have lost half of</s></s></s>
# -> Beta-VAE:	 <s>When Ben Benoit was just 15 years old, he was diagnosed with a rare form of cancer. But when Benoit was diagnosed with breast cancer in 2010, doctors told Ben that he could not afford to have breast cancer. So when Benoit was diagnosed with breast cancer in 2010, doctors told Ben that he</s></s></s>
# --------------------------------------------------------------------------------
# Step 1
#
# -> MMD-VAE:	 <s>When she was 4 years old, she lost her left eye in Hawaii. Then, 24 years later, Maarah Taylor was left blind in California. Her eyesight could never match Mimi Coats, 14, after suffering from rare heart disease -- one of the earliest known cases of lung cancer. Now she</s></s></s>
# -> Beta-VAE:	 <s>The day before he was diagnosed with a rare form of bone cancer, Ben Benoit was in a wheelchair. Benoit was in a wheelchair when doctors told him he could not walk. But when Benoit was diagnosed with bone cancer in 2010, doctors told Benoit that he could not walk. Benoit,</s></s></s>
# --------------------------------------------------------------------------------
# Step 2
#
# -> MMD-VAE:	 <s>When she was 4 years old, Laura Lauen lost her left eye in 2007. Then, she couldn't see in 24 hours. Wham! The California-based cancer survivor, then 14, had been left with small signs of cancer after her eye loss could soon be treated as a stroke. "In</s></s></s>
# -> Beta-VAE:	 <s>By. Ashley Collman. When Beni Coney was just eight months old, doctors told her she would never walk again. But when she was diagnosed with a rare form of bone cancer, the California-based dental worker was able to keep her legs on. Beni Coney, now 22, has</s></s></s>
# --------------------------------------------------------------------------------
# Step 3
#
# -> MMD-VAE:	 <s>When she was 14 years old, Amy Brownlee lost her left eye in Hong Kong. She then suffered from lung cancer, quick-acting cancer. "Amazingly, the odds of her survival could be much lower," said Rotterdam-based medical director Tim Howard. Now 24, Brownlee has been</s></s></s>
# -> Beta-VAE:	 <s>By. Ashley Collman. When Beni Hawley was born with a rare form of cancer, doctors told her she would have to wait until the end of the year to have a lung transplant. But despite the odds, Hawley has defied odds and survived despite being born with a rare form of cancer.</s></s></s>
# --------------------------------------------------------------------------------
# Step 4
#
# -> MMD-VAE:	 <s>Hong Kong (CNN) -- When blind Victoria Brown was 14, she lost her left eye in the Pacific Ocean. Relatives of her then-apartheid victim said she could no longer see, after weeks of medical treatment. "The number of microbe infections is terrible," said Daryl Brown, who lives</s></s></s>
# -> Beta-VAE:	 <s>By. Jennifer Newton. When Beni Hawkes was born with a massive brain tumour, doctors failed to find a suitable donor for him. Now, the 24-year-old is fighting to save his life by donating his brain to a charity. Beni Hawkes, from San Francisco, California,</s></s></s>
# --------------------------------------------------------------------------------
# Step 5
#
# -> MMD-VAE:	 <s>(CNN) -- Relieved after Hurricane Haiyan smashed into her home in the Australian Pacific, Victoria's medical examiner said Tuesday. Many people were blind, then lost vision. "The number of blind people will be 10 to 14 years old," said Biwa Brown, who said her recent aid has been "</s></s></s>
# -> Beta-VAE:	 <s>(CNN) -- San Francisco Giants pitcher Brad Paxton was hospitalized Friday after suffering a seizure and was rushed to a hospital in San Francisco. The San Francisco Giants pitcher, who is the team's best-ever pitcher, was taken to a hospital in San Francisco on Friday night after suffering a seizure. "We</s></s></s>
# --------------------------------------------------------------------------------
# Step 6
#
# -> MMD-VAE:	 <s>(CNN)Relieved after Hurricane Katrina smashed the Australian capital, Victoria, she said "human suffering" was in her hands. Many people could lose their mobile phones. The National Weather Service said Saturday that 9,000 displaced people have now died from post-human heat exhaustion, aspirin, blood pressure</s></s></s>
# -> Beta-VAE:	 <s>(CNN) -- San Francisco Giants pitcher Brad Paxton was hospitalized Friday after suffering a stroke, the San Francisco Giants said. The team said Paxton was taken to a hospital in San Francisco to undergo a CT scan and assess his condition. "We are praying for his recovery and that he will be able to</s></s></s>
# --------------------------------------------------------------------------------
# Step 7
#
# -> MMD-VAE:	 <s>(CNN)Relieved after Hurricane Pamunya smashed the Australian capital, Victoria, human resources workers said Saturday they would lose "very much." The number of people reported missing has been "very low," said Cyclone Kevin. Australian Red Cross volunteers say the thermal imaging system could save their lives in Bunchy</s></s></s>
# -> Beta-VAE:	 <s>(CNN) -- Typhoon Haiyan lashed the Philippines on Friday, killing at least 16 people and leaving at least 40 injured, the World Health Organization said. The World Health Organization said Haiyan's winds were "very strong" and the damage was "very severe." The agency said Haiyan's winds were "</s></s></s>
# --------------------------------------------------------------------------------
# Step 8
#
# -> MMD-VAE:	 <s>(CNN)Relieved Australian people reported "unhumanitarian collapse," the Red Cross said Saturday after Hurricane Pamela smashed through the capital of Darwin. The devastation will mean that many people had their mobile phones, food and medical supplies. Australian Red Cross chief Karen Buncher said "humanitarian needs are very low</s></s></s>
# -> Beta-VAE:	 <s>(CNN) -- Flooding in the remote Indonesian island of Bali left at least 16 people dead and hundreds injured, the country's disaster agency said Friday. Rescue workers worked to save the victims of the flooding in Bali's Bali province. "The situation is extremely dire," said Sanjay Kumar,</s></s></s>
# --------------------------------------------------------------------------------
# Step 9
#
# -> MMD-VAE:	 <s>(CNN)Relieved Australian authorities reported "unprecedented destruction," the Red Cross said after Typhoon Pamunu smashed the capital of Port-au-Prince. Humanitarian groups said the devastation will be huge. "People across the world have reported burning food, shelter and food aid," said Karen Brel</s></s></s>
# -> Beta-VAE:	 <s>(CNN) -- Floods and landslides in the central Philippines left at least 30 people dead and hundreds injured Saturday, the country's disaster agency said. The National Disaster Management Agency said the situation was "very serious" and said it was working to rescue the injured. "The relief agencies are working to ensure</s></s></s>
# --------------------------------------------------------------------------------
# **************************************************
# ** TARGET SENTENCE:
# **************************************************
# <s>(CNN)Relief workers reported "unbelievable destruction" after Tropical Cyclone Pam smashed the capital of Vanuatu, the Australian Red Cross said Saturday. The Australian Red Cross said via Twitter that "humanitarian needs will be enormous. Many people have lost their homes. Shelter, food and water</s>
