# %%
import sys; sys.path.append("../")

# Functions from my code
from dataset_wrappper import NewsData
from utils_train import transfer_batch_to_device
from utils_evaluation import tokenizer_batch_decode
from run_validation import load_model_for_eval

# General libs
import os
from pathlib import Path
from transformers import RobertaTokenizerFast
import torch
import numpy as np
import copy
import pickle
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
plt.style.reload_library()
plt.style.use('thesis_style')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# Globals
BATCH_SIZE = 200
DEVICE = "cuda:0"
CHECKPOINT_TYPE = "best" # else "best"
RESULT_DIR = Path("result-files")

# Data
data = NewsData(batch_size=BATCH_SIZE, tokenizer_name="roberta", dataset_name="ptb_text_only", max_seq_len=64)
# data = NewsData(batch_size=BATCH_SIZE, tokenizer_name="roberta", dataset_name="cnn_dailymail", max_seq_len=64)
validation_loader = data.val_dataloader(batch_size=BATCH_SIZE)
train_loader = data.train_dataloader()
tokenizer = RobertaTokenizerFast.from_pretrained('roberta-base')
# Out:
# Is file!
# train 42068
# validation 3370
# test 3761

# %%
def get_clean_name(run_name):
    if "latent32" in run_name:
        latent_size = 32
    elif "latent64" in run_name:
        latent_size = 64
    else:
        latent_size = 768
    #latent_size = run_name.split("-")[4][-2:]
    if "autoencoder" in run_name:
        FB = "autoencoder"
    else:
        FB = run_name.split("-")[6]
        if len(FB) == 3:
            FB += "0"
        FB = "FB-" + FB
    clean_name = f"NZ-{latent_size} | {FB}"
    return clean_name

PTB_run_name_paths = {}
for r in os.listdir("../Runs"):
    if "PTB" in r:
        path = Path("../Runs") / r / f"checkpoint-{CHECKPOINT_TYPE}.pth"
        PTB_run_name_paths[r] = path

clean_names = []
for r in PTB_run_name_paths.keys():
#     print(get_clean_name(r))
    clean_names.append(get_clean_name(r))
    
clean_names = sorted(clean_names)
for i, n in enumerate(clean_names):
    print(i, "\t", n)
# Out:
# 0 	 NZ-32 | FB-0.00
# 1 	 NZ-32 | FB-0.25
# 2 	 NZ-32 | FB-0.50
# 3 	 NZ-32 | FB-0.75
# 4 	 NZ-32 | FB-1.00
# 5 	 NZ-32 | FB-1.50
# 6 	 NZ-32 | autoencoder
# 7 	 NZ-32 | autoencoder
# 8 	 NZ-64 | FB-0.00
# 9 	 NZ-64 | FB-0.25
# 10 	 NZ-64 | FB-0.50
# 11 	 NZ-64 | FB-0.75
# 12 	 NZ-64 | FB-1.00
# 13 	 NZ-64 | FB-1.50
# 14 	 NZ-64 | autoencoder
# 15 	 NZ-64 | autoencoder
# 16 	 NZ-768 | autoencoder
# 17 	 NZ-768 | autoencoder
# 18 	 NZ-768 | autoencoder
# 19 	 NZ-768 | autoencoder
# 20 	 NZ-768 | autoencoder
# 21 	 NZ-768 | autoencoder
# 22 	 NZ-768 | autoencoder

# %% [markdown]
# ## 1 Collect latents of the whole train set for a few runs

# %%
runs =  [
 "2021-02-03-PTB-latent32-FB-0.5-run-09:31:02", 
 "2021-02-03-PTB-latent32-FB-1.50-run-12:13:36",
 "2021-02-03-PTB-latent32-autoencoder-run-17:30:41",
 "2021-03-01-1MAR-PTB-latent32-autoencoderEmbeddings-run-18:26:18"]

result_file = "train_latents.pickle"

# if os.path.isfile(result_file):
#     print(f"Load latents from file {result_file}")
#     latents_runs = pickle.load( open( result_file, "rb" ) )
# else: 
print(f"Compute latents on train set...")
# latents_runs = {}

for r, p in PTB_run_name_paths.items():

    if r not in runs:
        continue
    
    if r in latents_runs:
        continue

    print(get_clean_name(r))

    if "latent32" in r:
        latent_size = 32
    elif "latent64" in r:
        latent_size = 64
    else:
        latent_size = 768
        
    if "Embeddings" in r:
        add_latent_via_embeddings = True
    else:
        add_latent_via_embeddings = False
    vae_model = load_model_for_eval(p, device_name=DEVICE, 
                                    latent_size=latent_size, 
                                    add_latent_via_memory=True,
                                    add_latent_via_embeddings=add_latent_via_embeddings, 
                                    do_tie_weights=True, 
                                    do_tie_embedding_spaces=True,
                                    add_decoder_output_embedding_bias=False)

    latents, mus, logvars, strings = [], [], [], []

    for batch_i, batch in enumerate(train_loader):

        print(f"Batch {batch_i:3d} /{len(train_loader):3d}", end="\r")

        with torch.no_grad():
            batch = transfer_batch_to_device(batch, device_name=DEVICE)

            enc_out = vae_model.encoder.encode(batch["input_ids"], batch["attention_mask"], 
                                               n_samples=1,
                                               hinge_kl_loss_lambda=0.0,
                                               return_log_q_z_x=False,
                                               return_log_p_z=False,
                                               return_embeddings=False)

            latents.append(enc_out["latent_z"].cpu())
            mus.append(enc_out["mu"].cpu())
            logvars.append(enc_out["logvar"].cpu())
            strings.extend(tokenizer_batch_decode(batch["input_ids"].cpu(), tokenizer))

    latents = torch.cat(latents, dim=0)
    mus = torch.cat(mus, dim=0)
    logvars = torch.cat(logvars, dim=0)

    latents_runs[r] = {
        "latents": latents,
        "mus": mus,
        "logvars": logvars,
        "strings": strings
    }

pickle.dump( latents_runs, open( result_file, "wb" ) )
# Out:
# Compute latents on train set...
# NZ-32 | autoencoder
# Loading model...
# Replacing linear output layer with one without bias!
# Some weights of the model checkpoint at roberta-base were not used when initializing VAE_Encoder_RobertaModel: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VAE_Encoder_RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
# Done model...
# Loading VAE_model, optimizer and scheduler from ../Runs/2021-03-01-1MAR-PTB-latent32-autoencoderEmbeddings-run-18:26:18/checkpoint-best.pth
# Removing module string from state dict from checkpoint
# Checkpoint global_step: best, epoch: 22, best_valid_loss: 76.88829040527344
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# /home/cbarkhof/.conda/envs/thesisenv/lib/python3.6/site-packages/datasets/arrow_dataset.py:847: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.tensor(x, **format_kwargs)
# Batch 210 /211

# %% [markdown]
# ## 2 Compute neares neighbors of samples from the priors to latents from the train set

# %%
# Get some samples from the prior

latent_size = 32
scale = 1.0  # <-- standard normal
n_samples = 10
loc = torch.zeros(latent_size, device="cpu")
std = torch.ones(latent_size, device="cpu") * scale
prior_dist = torch.distributions.normal.Normal(loc, std)
prior_samples = prior_dist.sample((n_samples,))

# %%
from sklearn.neighbors import NearestNeighbors

n_neighbors = 5

runs =  [
 "2021-02-03-PTB-latent32-FB-0.5-run-09:31:02", 
 "2021-02-03-PTB-latent32-FB-1.50-run-12:13:36",
 "2021-02-03-PTB-latent32-autoencoder-run-17:30:41",
 "2021-03-01-1MAR-PTB-latent32-autoencoderEmbeddings-run-18:26:18"]

for r in runs:
    print("*"*50)
    print(r)
    print("*"*50)
    print()
    
    # Get the mean of the posteriors as the encodings
    posterior_means = latents_runs[r]["mus"]
    
    # Load the correct model
    
    if "latent32" in r:
        latent_size = 32
    elif "latent64" in r:
        latent_size = 64
    else:
        latent_size = 768
        
    p = PTB_run_name_paths[r]
    
    if "Embeddings" in r:
        add_latent_via_embeddings = True
    else:
        add_latent_via_embeddings = False
    
    vae_model = load_model_for_eval(p, device_name=DEVICE, 
                                    latent_size=latent_size, 
                                    add_latent_via_memory=True,
                                    add_latent_via_embeddings=add_latent_via_embeddings, 
                                    do_tie_weights=True, 
                                    do_tie_embedding_spaces=True,
                                    add_decoder_output_embedding_bias=False)
    print("\n\n")
    print("-"*30)

    # Make a brute-forced nearest neighbor graph of the validation set, find 10 neighbors
    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='brute').fit(posterior_means.numpy())

    # Get the closest data train posterior means to a sample from the prior
    # distances between those and indices of the initial graph (corresponding to latents matrix)
    distances, indices = nbrs.kneighbors(prior_samples.cpu().numpy())

    # Go over the samples in the priors and evaluate the closest train posteriors
    for s_i in range(len(prior_samples)):

        sample_from_prior = prior_samples[s_i, :]

        closest_post_means_train = []
        closest_string_train = []

        ds = []
        for idx, d in zip(indices[s_i], distances[s_i]):

            closest_post_means_train.append(posterior_means[idx, :])
            closest_string_train.append(latents_runs[r]["strings"][idx])
            ds.append(d)

        sample_and_train_neighbors = torch.stack([sample_from_prior] + closest_post_means_train, dim=0).to(DEVICE)
        
        vae_model.eval()
        with torch.no_grad():
            dec = vae_model.decoder.autoregressive_decode(sample_and_train_neighbors,
                                                          labels=None,
                                                          max_seq_len=32,
                                                          return_exact_match=False,
                                                          return_cross_entropy=False,
                                                          return_attention_probs=False,
                                                          return_attention_to_latent=False,
                                                          return_hidden_states=False,
                                                          return_last_hidden_state=False,
                                                          return_predictions=True,
                                                          return_probabilities=False,
                                                          return_output_embeddings=False,
                                                          return_logits=False,
                                                          nucleus_sampling=False, # <-- to check variability from the latent turn this off
                                                          reduce_seq_dim_ce="sum",
                                                          reduce_seq_dim_exact_match="none",
                                                          reduce_batch_dim_exact_match="none",
                                                          reduce_batch_dim_ce="mean",
                                                          device_name=DEVICE)
        
        # The first prediction is the one belonging to the sample from prior
        # the rest are reconstructions of the posterior mean encodings
        
        # Post process the strings, cutting of padding etc.
        text = tokenizer_batch_decode(dec["predictions"], tokenizer)
        N = len(text)
        text += closest_string_train
        ts = []
        for t in text:
            if "<s>" in t:
                t = t[3:]
            index_end = t.find("</s>")
            if index_end == -1:
                ts.append(t)
            else:
                ts.append(t[:index_end])
                
        closest_string_train = ts[N:]
        text = ts[:N]

        print("Sample from prior decoded:\n", ts[0])
        print("-"*60)
        print("Means from train sample latents that lay closest:")
        for i, (recon, orig) in enumerate(zip(ts[1:], closest_string_train)):
            print(f"{i} -- D = {ds[i]:.2f}")
            print("** Auto-regressive reconstruction:\n", recon)
            print("** Original string:\n", orig)
            print()
        print("-"*60)
        print("-"*60)
        print()
# Out:
# **************************************************
# 2021-02-03-PTB-latent32-FB-0.5-run-09:31:02
# **************************************************
#
# Loading model...
# Replacing linear output layer with one without bias!
# Some weights of the model checkpoint at roberta-base were not used when initializing VAE_Encoder_RobertaModel: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VAE_Encoder_RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
# Done model...
# Loading VAE_model, optimizer and scheduler from ../Runs/2021-02-03-PTB-latent32-FB-0.5-run-09:31:02/checkpoint-best.pth
# Removing module string from state dict from checkpoint
# Checkpoint global_step: best, epoch: 37, best_valid_loss: 84.10610651086878
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
#
#
#
# ------------------------------
# Sample from prior decoded:
#  <unk> <unk>
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.43
# ** Auto-regressive reconstruction:
#  the <unk> <unk> was a <unk> for the <unk>
# ** Original string:
#  with the $ N million received from investors he took frequent <unk> with friends to exotic <unk> and leased an expensive <unk> for his girlfriend whom he met at the shop where he got his <unk> suits
#
# 1 -- D = 4.50
# ** Auto-regressive reconstruction:
#  the <unk> <unk> was a <unk> of the <unk> of the <unk>
# ** Original string:
#  united's directors voted themselves and their spouses lifetime access to the friendly <unk> free <unk> travel and $ N a year for life as well
#
# 2 -- D = 4.55
# ** Auto-regressive reconstruction:
#  mr. <unk> was a <unk> <unk> at the university of minnesota
# ** Original string:
#  he <unk> the company with grant <unk> and mary tyler moore in N
#
# 3 -- D = 4.62
# ** Auto-regressive reconstruction:
#  <unk> <unk> a <unk> in the u.s. was elected to the board of this insurance company
# ** Original string:
#  he started arrow <unk> inc. a year ago with a loan from a friend since repaid and now employs N
#
# 4 -- D = 4.67
# ** Auto-regressive reconstruction:
#  the <unk> <unk> was a <unk>
# ** Original string:
#  sometimes the <unk> became partners in the company
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the two men met in N and met in N
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.91
# ** Auto-regressive reconstruction:
#  the u.s. attorney's office filed a complaint in federal court in manhattan charging the u.s. attorney with engaging in a pattern of
# ** Original string:
#  the ad prompted mr. coleman the former virginia attorney general to launch a series of advertisements created by bob goodman and designed to shake mr. wilder's support among the very women who were attracted by the abortion ad
#
# 1 -- D = 4.08
# ** Auto-regressive reconstruction:
#  the u.s. attorney's office filed a criminal complaint against mr. <unk> in federal court in manhattan charging him with conspiracy to
# ** Original string:
#  your oct. N editorial the ill homeless referred to research by us and six of our colleagues that was reported in the sept. N issue of the journal of the american medical association
#
# 2 -- D = 4.10
# ** Auto-regressive reconstruction:
#  the judge also ruled that the defendants were <unk> and that the defendants were defendants in a scheme to <unk> the government of $ N million
# ** Original string:
#  one plaintiff a doctor testified in an affidavit that he also gave mr. peterson $ N to join a sort of investment club which essentially gave the physician the privilege of making additional investments with mr. peterson
#
# 3 -- D = 4.11
# ** Auto-regressive reconstruction:
#  the <unk> was a <unk> of the <unk> of the <unk> of the <unk>
# ** Original string:
#  the articles were largely based on interviews ms. malcolm had taped with jeffrey masson a <unk> who had served as projects director of the <unk> <unk>
#
# 4 -- D = 4.12
# ** Auto-regressive reconstruction:
#  mr. <unk> was a former vice president of the national association of manufacturers of engineers
# ** Original string:
#  a columnist in the atlanta journal and constitution wrote who did the research for this report
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  mr. <unk> said the <unk> will be <unk> by the end of the year
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.76
# ** Auto-regressive reconstruction:
#  the <unk> <unk> said the move is part of a strategy to reduce costs and boost productivity
# ** Original string:
#  argentina <unk> to reach a reduction of N N in the value of its external debt mr. <unk> said through his spokesman <unk> <unk>
#
# 1 -- D = 4.81
# ** Auto-regressive reconstruction:
#  the u.s. has been <unk> to the contras for months and has been trying to <unk> the contras with economic aid
# ** Original string:
#  asked about the possibility of greater economic cooperation among <unk> nations which will be discussed nov. N and N at a <unk> meeting in <unk> mr. lee said the goal is to have a free and open world trading system
#
# 2 -- D = 4.84
# ** Auto-regressive reconstruction:
#  the <unk> <unk> of the u.s. trade group's annual meeting in <unk> monday was expected to be a major topic of discussion
# ** Original string:
#  trade and supply minister <unk> <unk> said in a letter published in the youth daily <unk> <unk> that the rise in alcohol consumption in east germany had been halted but to reduce it further he said production and supply of other <unk> including fruit <unk> should be stepped up
#
# 3 -- D = 4.84
# ** Auto-regressive reconstruction:
#  mr. <unk> said the u.s. is prepared to accept any <unk> proposal by the soviet union
# ** Original string:
#  he said prime minister <unk> <unk> also is studying the possibility of a visit to the two eastern bloc nations and to western europe next january
#
# 4 -- D = 4.85
# ** Auto-regressive reconstruction:
#  mr. <unk> said the u.s. is <unk> to the <unk> of the u.s. <unk>
# ** Original string:
#  mr. <unk> said at a convention in west berlin that the union has to prepare for a big fight to achieve its main goal of a <unk> <unk> down from current <unk> <unk>
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the average of the N largest banks in the nation was N N
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.63
# ** Auto-regressive reconstruction:
#  the problem is that the government's own spending is too large
# ** Original string:
#  because of the way the government keeps its books the damage to the bay bridge however costly won't be counted as a minus
#
# 1 -- D = 3.63
# ** Auto-regressive reconstruction:
#  the minimum unit is $ N
# ** Original string:
#  but the total value of the prizes was only $ N and most winners will receive just N cents according to the attorney general's office
#
# 2 -- D = 3.65
# ** Auto-regressive reconstruction:
#  the company's earnings were down N N from a year earlier
# ** Original string:
#  compliance added N N to N N to her accounting bill last year she says
#
# 3 -- D = 3.65
# ** Auto-regressive reconstruction:
#  the minimum unit is $ N
# ** Original string:
#  both returns don't include any tax credits
#
# 4 -- D = 3.66
# ** Auto-regressive reconstruction:
#  but the cost of the project wasn't known
# ** Original string:
#  that's because only about N N of california homes and businesses had earthquake insurance to cover the losses
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  mr. <unk> is a consultant to the u.s. chamber of commerce
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.08
# ** Auto-regressive reconstruction:
#  the <unk> of the u.s. isn't the only major player in the game
# ** Original string:
#  at the same time viacom is trying to persuade stations to make commitments to a different world a <unk> of cosby whose reruns will become available in N
#
# 1 -- D = 5.12
# ** Auto-regressive reconstruction:
#  but the <unk> of the u.s. isn't likely to be enough
# ** Original string:
#  that may not come as a surprise to americans who have watched the japanese <unk> up properties in the u.s. from golf courses to a stake in rockefeller center
#
# 2 -- D = 5.17
# ** Auto-regressive reconstruction:
#  the <unk> is a <unk>
# ** Original string:
#  but cbs will put the athletes up against bill cosby <unk> and other shows in nbc's no. N schedule
#
# 3 -- D = 5.20
# ** Auto-regressive reconstruction:
#  the u.s. has been <unk> by the soviets for years and is trying to <unk> the u.s.
# ** Original string:
#  the u.s. is worried about the <unk> of olivetti's machine tools to military use
#
# 4 -- D = 5.21
# ** Auto-regressive reconstruction:
#  but the <unk> of the u.s. isn't the only problem facing the u.s.
# ** Original string:
#  this well may be the first time that the venerable rockefeller university has brushed up publicly against the <unk> now common in american science
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# Sample from prior decoded:
#  but the problem is that the fed isn't <unk> to the problem
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.64
# ** Auto-regressive reconstruction:
#  but the market isn't as easy as it used to be
# ** Original string:
#  there's a rising fear that perhaps mrs. thatcher's style of management has become a political liability says bill martin senior economist at london brokers <unk> & drew
#
# 1 -- D = 4.69
# ** Auto-regressive reconstruction:
#  but the <unk> of the fed's policy isn't likely to change
# ** Original string:
#  what's worrying her supporters is that the economic cycle may be out of <unk> with the political timetable
#
# 2 -- D = 4.70
# ** Auto-regressive reconstruction:
#  but it's not clear whether the <unk> of the <unk> is enough to topple the government
# ** Original string:
#  but i feel that if somebody doesn't get up and start talking about this now the next time around when we have the next <unk> of these programs it will still be true that everyone is scared to talk about it
#
# 3 -- D = 4.71
# ** Auto-regressive reconstruction:
#  but he adds that the market isn't going to be as volatile as it was last week
# ** Original string:
#  i think the dynamics of this situation are that something's got to happen said one official familiar with the situation
#
# 4 -- D = 4.72
# ** Auto-regressive reconstruction:
#  but the <unk> of the fed's policy isn't the only problem
# ** Original string:
#  what's surprising is that there isn't more of a conservative outcry as the bush administration lets the programs slip down the <unk> list
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the company's earnings were up N N from a year earlier
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.39
# ** Auto-regressive reconstruction:
#  the company said the results were influenced by the strength of the dollar and the strength of the yen
# ** Original string:
#  analysts were predicting N bellsouth earnings in the range of $ N a share or $ N billion but now those estimates are being scaled back
#
# 1 -- D = 4.46
# ** Auto-regressive reconstruction:
#  the company said the results were based on a N N increase in revenue to $ N million from $ N million
# ** Original string:
#  analysts said those estimates which range from about $ N a share to $ N a share are based on fantasy being in operation in N
#
# 2 -- D = 4.48
# ** Auto-regressive reconstruction:
#  but the company's stock has been trading at around N N of its earnings since the stock market's plunge oct. N
# ** Original string:
#  but analysts estimate their trading profit at # N million
#
# 3 -- D = 4.49
# ** Auto-regressive reconstruction:
#  the dow jones industrial average fell N points to N
# ** Original string:
#  estimates from traders put it at less than N N of nasdaq's average daily volume of roughly N million shares
#
# 4 -- D = 4.49
# ** Auto-regressive reconstruction:
#  the stock fell N cents in composite trading on the new york stock exchange friday to close at $ N a share
# ** Original string:
#  the firm said that losers outnumbered gainers by more than three to one among the N funds it tracks
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the company also will pay a special dividend of N cents a share on the common stock payable dec. N to stock of record nov. N
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.44
# ** Auto-regressive reconstruction:
#  the company said it will sell the shares to the holders of about $ N million in cash and securities
# ** Original string:
#  the directors would be able to sell particular assets to enable such buyers as the regional bell operating companies to purchase the company's interests
#
# 1 -- D = 4.49
# ** Auto-regressive reconstruction:
#  the company said it will sell the assets to the new company and to the shareholders
# ** Original string:
#  the pilots could borrow against the value of their concessions using the proceeds to buy back stock from the public and give themselves the majority control they have been seeking
#
# 2 -- D = 4.49
# ** Auto-regressive reconstruction:
#  the company said it will sell the assets to focus on its core businesses of insurance and property management
# ** Original string:
#  the realty unit might take on new debt or obtain additional investors among other possibilities
#
# 3 -- D = 4.51
# ** Auto-regressive reconstruction:
#  the offer is subject to approval by the board of the company's board
# ** Original string:
#  the new structure would be similar to a recapitalization in which holders get a special dividend yet retain a controlling ownership interest
#
# 4 -- D = 4.54
# ** Auto-regressive reconstruction:
#  the company hasn't yet disclosed its financial results for the nine months
# ** Original string:
#  since most of its assets are tied to manville a forest and building products concern the trust might also want to diversify its holdings
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  mr. <unk> is a columnist for the wall street journal's new york bureau
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.26
# ** Auto-regressive reconstruction:
#  mr. <unk> says he hasn't yet seen the suit and that he won't be surprised if it is filed by the company
# ** Original string:
#  and mr. <unk> the program producer contends that kodak's move is a sound marketing decision
#
# 1 -- D = 3.36
# ** Auto-regressive reconstruction:
#  mr. <unk> said the company is considering a <unk> plan
# ** Original string:
#  dr. <unk> said searle is the only company i know that voluntarily will make consumer information available
#
# 2 -- D = 3.38
# ** Auto-regressive reconstruction:
#  the company hasn't yet been <unk> by the <unk>
# ** Original string:
#  among the other <unk> are stephen wolf now chairman of ual inc. and thomas <unk> president of pan am corp
#
# 3 -- D = 3.41
# ** Auto-regressive reconstruction:
#  mr. <unk> is a consultant to the <unk> institute
# ** Original string:
#  jamie <unk> president of fox broadcasting said we believe the partnership of fox its affiliates and advertisers is succeeding and will continue to grow
#
# 4 -- D = 3.42
# ** Auto-regressive reconstruction:
#  mr. <unk> is a columnist for the wall street journal's new york bureau
# ** Original string:
#  one early user david <unk> a chicago venture capitalist and investor in desktop data says he uses it to track takeover developments
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  mr. bush has been <unk> for months
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.14
# ** Auto-regressive reconstruction:
#  but the u.s. hasn't yet shown that it is ready to take the lead
# ** Original string:
#  asked why so few nations seem to share his views of america he said many people see it that way
#
# 1 -- D = 5.14
# ** Auto-regressive reconstruction:
#  but the u.s. isn't alone in its desire to change its ways
# ** Original string:
#  obviously it's lost on you that about N N of the american people these days and in fact the president of the united states consider themselves environmentalists
#
# 2 -- D = 5.15
# ** Auto-regressive reconstruction:
#  mr. bush has been pushing for a line-item veto but he hasn't been willing to <unk> the president's power to veto legislation
# ** Original string:
#  mr. baker may want to avoid criticism from senate majority leader george mitchell but as secretary of state his audience is the entire free world not just congress
#
# 3 -- D = 5.17
# ** Auto-regressive reconstruction:
#  mr. bush's remarks were interpreted as a sign that he isn't interested in <unk> the bush administration
# ** Original string:
#  mr. honecker spoke of generally valid objective laws of socialism and left no room for debate
#
# 4 -- D = 5.18
# ** Auto-regressive reconstruction:
#  but he said the <unk> of the u.s. hasn't yet been fully <unk>
# ** Original string:
#  if mr. gates had been allowed to say these things we would now be hearing about <unk> and disarray on foreign policy
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# **************************************************
# 2021-02-03-PTB-latent32-FB-1.50-run-12:13:36
# **************************************************
#
# Loading model...
# Replacing linear output layer with one without bias!
# Some weights of the model checkpoint at roberta-base were not used when initializing VAE_Encoder_RobertaModel: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VAE_Encoder_RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
# Done model...
# Loading VAE_model, optimizer and scheduler from ../Runs/2021-02-03-PTB-latent32-FB-1.50-run-12:13:36/checkpoint-best.pth
# Removing module string from state dict from checkpoint
# Checkpoint global_step: best, epoch: 56, best_valid_loss: 71.11977527759693
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
#
#
#
# ------------------------------
# Sample from prior decoded:
#  they invested $ N in <unk> <unk> a young couple who wanted to buy a <unk> house and bought a couple of golf courses
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.16
# ** Auto-regressive reconstruction:
#  he bought his <unk> in a <unk> market and sold them in other small california cities
# ** Original string:
#  he used to be a <unk> salesman peddling investments in oil and gas wells and rare coins
#
# 1 -- D = 4.23
# ** Auto-regressive reconstruction:
#  with money from the sale of his <unk> and his wife and two sons he bought a place in the <unk> and spent a few hundred thousand dollars on
# ** Original string:
#  with the $ N million received from investors he took frequent <unk> with friends to exotic <unk> and leased an expensive <unk> for his girlfriend whom he met at the shop where he got his <unk> suits
#
# 2 -- D = 4.27
# ** Auto-regressive reconstruction:
#  with their support they have <unk> a <unk> of charities to spend their money
# ** Original string:
#  having donated heavily to <unk> they demand a place on their boards
#
# 3 -- D = 4.31
# ** Auto-regressive reconstruction:
#  he started his business in <unk> n.y. in N and sold it to a <unk> group in N
# ** Original string:
#  he started arrow <unk> inc. a year ago with a loan from a friend since repaid and now employs N
#
# 4 -- D = 4.32
# ** Auto-regressive reconstruction:
#  they're trying to <unk> the <unk> kids in their <unk> and they're raising a lot of money says mary <unk> a marketing
# ** Original string:
#  they're hiring models to <unk> the <unk> sporting their <unk> and they're even beginning to borrow a <unk> favorite of the beauty business offering a gift when consumers make a purchase
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  one memo from mr. engelken made in response to the suit by ms. malcolm's husband james a former vice president and now
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.73
# ** Auto-regressive reconstruction:
#  the author of the book <unk> of the <unk> and <unk> of the <unk> in N is a former <unk> at the university of minnesota
# ** Original string:
#  the writer and executive producer of settle the score steve sohmer is a graduate of yale who participated in a pbs <unk> aired this summer in which six members of the yale class of N <unk> about their lives since <unk>
#
# 1 -- D = 3.78
# ** Auto-regressive reconstruction:
#  according to mr. <unk> the agreement calls for the two companies to jointly produce a high-quality television program for independent television stations
# ** Original string:
#  among other things mr. bologna said that the sale will facilitate gen-probe's marketing of a diagnostic test for acquired immune deficiency syndrome or aids
#
# 2 -- D = 3.86
# ** Auto-regressive reconstruction:
#  one of the group's new directors will be david d. <unk> a former cbs sports executive who will run the ad agency for ddb need
# ** Original string:
#  one for example came from cbs records chairman walter yetnikoff who will head a committee that will oversee sony's entertainment division including both records and movies
#
# 3 -- D = 3.90
# ** Auto-regressive reconstruction:
#  the writer and director of the play also is <unk> by the <unk> of the <unk> who asked not to be identified but says the producers are considering
# ** Original string:
#  the editor also says the new producer on the film bruce <unk> told editors to screen the picture without telling stars <unk> <unk> and kurt russell or mr. peters
#
# 4 -- D = 3.91
# ** Auto-regressive reconstruction:
#  <unk> a literary critic in new york contributed to this article by <unk> <unk> a former staff reporter at the new york times
# ** Original string:
#  <unk> malcolm a professional writer on psychiatric matters wrote a series of articles for the new yorker later published in book form by <unk> under the title in the <unk> <unk>
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  a <unk> delegation of opec chief <unk> <unk> said he would aim for a reduction of all <unk> emissions
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.40
# ** Auto-regressive reconstruction:
#  richard <unk> president of the <unk> group says the group is growing more and more <unk>
# ** Original string:
#  dan <unk> leader of the <unk> group sees benefits all around
#
# 1 -- D = 4.56
# ** Auto-regressive reconstruction:
#  a joint venture with mr. hahn would make u.s. sales of its own product
# ** Original string:
#  an executive model would significantly boost jaguar's yearly output of N cars
#
# 2 -- D = 4.63
# ** Auto-regressive reconstruction:
#  meanwhile he is seeking a political and economic solution to the problem that is <unk> the country's economy into a <unk> deficit
# ** Original string:
#  managing change he adds will require a lot more aid and a prominent role for the ec especially in dealing with the question of german reunification
#
# 3 -- D = 4.64
# ** Auto-regressive reconstruction:
#  he said the u.s. should help <unk> the contras to control their territory
# ** Original string:
#  he said u.s. assistance should be used to <unk> the rebels
#
# 4 -- D = 4.64
# ** Auto-regressive reconstruction:
#  u.s. <unk> will assume the <unk> role of <unk> in the european community after the withdrawal of mr. lawson
# ** Original string:
#  argentina <unk> to reach a reduction of N N in the value of its external debt mr. <unk> said through his spokesman <unk> <unk>
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  it was the smallest loss on the new york stock exchange but the most in the N biggest markets
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.49
# ** Auto-regressive reconstruction:
#  but the real debt is in the junk bonds themselves
# ** Original string:
#  but this is not where the rewards of junk financing were found
#
# 1 -- D = 3.53
# ** Auto-regressive reconstruction:
#  the bank doesn't issue notes
# ** Original string:
#  the paris bank doesn't publish that figure
#
# 2 -- D = 3.53
# ** Auto-regressive reconstruction:
#  according to one analyst the junk bond market was hit by a number of junk bonds that were sold by the government and sold by the bondholders association
# ** Original string:
#  according to a trader at drexel burnham lambert inc. the hardest hit junk bonds were those issued by rjr holdings capital corp. which are the <unk> to sell
#
# 3 -- D = 3.54
# ** Auto-regressive reconstruction:
#  but the dow jones industrial average fell N points in only N minutes of trading before recovering most of its losses by the end of the trading session
# ** Original string:
#  but the nikkei fell an overall N N in value that day compared with wall street's far sharper N N drop on oct. N
#
# 4 -- D = 3.55
# ** Auto-regressive reconstruction:
#  a passenger was injured and the bridge collapsed in the quake's violent shaking
# ** Original string:
#  barrels were dumped on the courter property a complaint was made but there is no evidence the barrels were a serious threat to the environment
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# Sample from prior decoded:
#  trouble is that the japanese are a <unk> of the japanese organization to the u.s.
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.77
# ** Auto-regressive reconstruction:
#  britain's current system of control is a <unk> of the power of perestroika which has been severely limited by the <unk> of
# ** Original string:
#  sverdlovsk is a large gray cloud over glasnost and indeed over the legitimacy of the arms-control process itself
#
# 1 -- D = 4.39
# ** Auto-regressive reconstruction:
#  japan is a major importer of the u.s.
# ** Original string:
#  japan is a major target for the soviets
#
# 2 -- D = 4.41
# ** Auto-regressive reconstruction:
#  besides being a big <unk> for the big board a big market for program trading is a big drain on <unk>
# ** Original string:
#  jumping in on big deals is a high profile way to <unk> the problem of not having a strong <unk> network
#
# 3 -- D = 4.44
# ** Auto-regressive reconstruction:
#  nissan hasn't decided how to finance its new strategy and mr. gandhi is expected to name a new chairman
# ** Original string:
#  finally mitsubishi estate has no plans to interfere with rockefeller's management beyond taking a place on the board
#
# 4 -- D = 4.53
# ** Auto-regressive reconstruction:
#  drexel's problem is that it will have to <unk> its junk-bond portfolio over a long period of time
# ** Original string:
#  nissan's risk is that its <unk> strategy might get lost amid the highly publicized rebates being offered by detroit's big three
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the people have a good sense of what we're seeing says david <unk> a new york city public relations consultant who has been looking for ways to
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.08
# ** Auto-regressive reconstruction:
#  there's a growing sense that mr. dinkins is a political prisoner of choice says mr. <unk> of the new york political
# ** Original string:
#  there's a rising fear that perhaps mrs. thatcher's style of management has become a political liability says bill martin senior economist at london brokers <unk> & drew
#
# 1 -- D = 4.18
# ** Auto-regressive reconstruction:
#  the idea is that the <unk> of the <unk> is something you can do for a bit but you have to be very careful to get burned
# ** Original string:
#  the thing about the dinkins <unk> is that it offers hope to a broad range of people says <unk> <unk> a real-estate executive and former aide to gov. mario <unk>
#
# 2 -- D = 4.25
# ** Auto-regressive reconstruction:
#  there's a lot of <unk> about the outlook for sterling said one senior trader at <unk> bank in frankfurt
# ** Original string:
#  there's a strong sense among the <unk> set that there's more bad news to come asserts roger <unk> chief investment officer at morgan grenfell asset management
#
# 3 -- D = 4.26
# ** Auto-regressive reconstruction:
#  you're telling people that the market for stocks was a big mistake and that it wasn't a big mistake says <unk> <unk> a money manager
# ** Original string:
#  our fear was people would look just at the beta of a gold fund and say here is an investment with very low risk says john <unk> director of research for the chicago-based group
#
# 4 -- D = 4.30
# ** Auto-regressive reconstruction:
#  we think there is a lot of interest in the bonds market said mr. <unk>
# ** Original string:
#  we see a lot of interest in those kind of things says frank <unk> a vice president of bankers trust
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  moody's has said that average operating margins have slipped N N to N N and that average operating margin is about N N
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.28
# ** Auto-regressive reconstruction:
#  a sharp drop in the stock market hasn't caused much to change the fundamentals of the stock market he said
# ** Original string:
#  a drop below that N N benchmark has always been a strong warning sign that stocks are fully valued says mr. boesel of t. rowe price
#
# 1 -- D = 4.30
# ** Auto-regressive reconstruction:
#  bond prices are more sensitive to changes in the economy as well as to the rate of inflation
# ** Original string:
#  shorter maturities are considered a sign of rising rates because portfolio managers can capture higher rates sooner
#
# 2 -- D = 4.30
# ** Auto-regressive reconstruction:
#  moody's said the N N junk bond due N fell N to N from N N to yield N N
# ** Original string:
#  moody's said the average net asset value of N junk-bond mutual funds fell by N N in october
#
# 3 -- D = 4.31
# ** Auto-regressive reconstruction:
#  some analysts say N N to N N of the company's total earnings are expected to be cut in half next year or so
# ** Original string:
#  some analysts have estimated ibm's fourth-quarter per-share earnings will fall N N to $ N a share from $ N a share a year earlier
#
# 4 -- D = 4.31
# ** Auto-regressive reconstruction:
#  i think the market is very sensitive to any signs of a recession he said
# ** Original string:
#  i'm somewhat skeptical about the underlying demand for polaroid products said michael <unk> an analyst with wertheim schroder & co
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  if the government can obtain the assets valued at $ N billion or more the government would retain the right to buy back as much as N N of the equity
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 4.42
# ** Auto-regressive reconstruction:
#  however a judge who will be in the u.s. district court of new york could force the company to pay as much as $ N million
# ** Original string:
#  sony for its part could decide that the cost of a warner settlement or court fight is too high choosing instead to find someone else to run columbia although that too would be costly given the financial arrangement already guaranteed to mr. guber and mr. peters
#
# 1 -- D = 4.45
# ** Auto-regressive reconstruction:
#  lawrence insurance co. said it will acquire the assets of the trust for $ N million in cash and securities
# ** Original string:
#  lawrence insurance based in albany n.y. plans to use the $ N million in proceeds to help finance the acquisition of united republic
#
# 2 -- D = 4.53
# ** Auto-regressive reconstruction:
#  in addition to the $ N million in bank debt the new company will also issue $ N million of convertible preferred stock and $ N million of convertible preferred stock
# ** Original string:
#  in addition a norfolk affiliate york capital inc. will purchase all of the interests of eagle's secured lenders which total $ N million and guarantee as much as $ N million in payments to eagle's unsecured creditors
#
# 3 -- D = 4.53
# ** Auto-regressive reconstruction:
#  under the plan the thrift would be liquidated and its assets held for $ N million in cash and stock to be sold by the new company according to
# ** Original string:
#  under it the former billionaire's assets would be liquidated with the irs getting N N of the proceeds and the rest being divided among other creditors including minpeco and manufacturers hanover trust co. which is seeking repayment of a $ N million loan
#
# 4 -- D = 4.53
# ** Auto-regressive reconstruction:
#  since the new rules force thrifts to pay higher interest rates than they paid on treasury bills the thrift is expected to pay about N N of its total
# ** Original string:
#  because columbia now must sell the bonds within five years accounting rules require the thrift to value the bonds at the lower of cost or market prices
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the executive is a member of a <unk> group of securities firms and individual investors
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 3.04
# ** Auto-regressive reconstruction:
#  a spokeswoman for the company said the company doesn't comment on speculation
# ** Original string:
#  a spokeswoman for paramount said the company doesn't comment on speculation
#
# 1 -- D = 3.07
# ** Auto-regressive reconstruction:
#  a company with a <unk> in debt isn't likely to be a good bet given that the thrift is a good fit says mr.
# ** Original string:
#  a company such as federal paper board may be overly discounted and looks <unk> to him he says though he isn't yet recommending the shares
#
# 2 -- D = 3.09
# ** Auto-regressive reconstruction:
#  a spokesman for georgia gulf said the company has no plans to acquire any other major energy companies
# ** Original string:
#  a spokesman for cs first boston said we remain committed to a full range of businesses including merchant banking
#
# 3 -- D = 3.16
# ** Auto-regressive reconstruction:
#  a spokesman for the chicago mercantile exchange said the exchange doesn't have any plans to sell the stock
# ** Original string:
#  a spokeswoman for ogilvy & mather said the agency doesn't comment on idle speculation
#
# 4 -- D = 3.18
# ** Auto-regressive reconstruction:
#  a <unk> has been a favorite among <unk> people in the past few years
# ** Original string:
#  a prominent businessman in <unk> gives a similar <unk> i have been taking it daily since N
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# Sample from prior decoded:
#  the white house is very much worried about mr. bush's <unk> that it is too hard to read congress
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.06
# ** Auto-regressive reconstruction:
#  mr. kasparov couldn't be reached for comment yesterday but he said the <unk> of the new crowd will be difficult for anyone outside the
# ** Original string:
#  mr. stoltzman must have worried that his audience might not be able to take it he warned us in advance that new york <unk> lasts N N minutes
#
# 1 -- D = 5.10
# ** Auto-regressive reconstruction:
#  mr. bush may not be a friendly man for the bush administration but he is likely to be able to persuade congress to <unk> its own rules
# ** Original string:
#  mr. baker may want to avoid criticism from senate majority leader george mitchell but as secretary of state his audience is the entire free world not just congress
#
# 2 -- D = 5.14
# ** Auto-regressive reconstruction:
#  i think the u.s. can be a model for democratic democracy
# ** Original string:
#  is an american secretary of state seriously suggesting that the khmer rouge should help govern cambodia
#
# 3 -- D = 5.24
# ** Auto-regressive reconstruction:
#  mr. bush was quoted as saying that such views weren't justified by the rigid rigid separation of powers
# ** Original string:
#  mr. honecker spoke of generally valid objective laws of socialism and left no room for debate
#
# 4 -- D = 5.26
# ** Auto-regressive reconstruction:
#  mr. katz points out that many people think the public should be paid more
# ** Original string:
#  mr. laband gives us an idea why economists'predictions are usually wrong
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# **************************************************
# 2021-02-03-PTB-latent32-autoencoder-run-17:30:41
# **************************************************
#
# Loading model...
# Replacing linear output layer with one without bias!
# Some weights of the model checkpoint at roberta-base were not used when initializing VAE_Encoder_RobertaModel: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VAE_Encoder_RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of VAE_Encoder_RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
# Done model...
# Loading VAE_model, optimizer and scheduler from ../Runs/2021-02-03-PTB-latent32-autoencoder-run-17:30:41/checkpoint-best.pth
# Removing module string from state dict from checkpoint
# Checkpoint global_step: best, epoch: 56, best_valid_loss: 62.82812358714916
# Tying encoder decoder RoBERTa checkpoint weights!
# <class 'modules.decoder_roberta_new.VaeDecoderRobertaModel'> and <class 'modules.encoder_roberta.VAE_Encoder_RobertaModel'> are not equal. In this case make sure that all encoder weights are correctly initialized.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Tying embedding spaces!
#
#
#
# ------------------------------
# Sample from prior decoded:
#  he signed up for N <unk> programs such as the life insurance broker and the death benefits act
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 7.19
# ** Auto-regressive reconstruction:
#  she moved to a new account and <unk> her billing history with a different irs bureau she says
# ** Original string:
#  she signed up starting as an inside adjuster who <unk> minor claims and does a lot of work by phone
#
# 1 -- D = 7.23
# ** Auto-regressive reconstruction:
#  he spent the next few weeks preparing for the u.s. <unk> and <unk> against hits
# ** Original string:
#  he made desperate efforts using the yellow pages from beginning to end said <unk> <unk> president of daiwa's u.s. unit
#
# 2 -- D = 7.30
# ** Auto-regressive reconstruction:
#  he spends most of his time <unk> his equipment with two <unk> he built for his own team
# ** Original string:
#  he spends most <unk> flying his helicopter to one of his nine courses he says two of which were designed by jack <unk>
#
# 3 -- D = 7.31
# ** Auto-regressive reconstruction:
#  they are encouraged to sign up for educational materials provided they are <unk> to their parents'<unk>
# ** Original string:
#  we accommodate their choice of names by allowing them to demonstrate family <unk> with legal documents says jim <unk> a senior vice president
#
# 4 -- D = 7.32
# ** Auto-regressive reconstruction:
#  mrs. <unk> introduced the <unk> of classic jewelry designs and she has made millions of them with diamonds
# ** Original string:
#  maidenform generated such <unk> campaigns as i <unk> i in my maidenform <unk> and the maidenform woman
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  he describes the first of several experiments called <unk> and a balloon balloon and notes that no human life will be threatened
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 6.94
# ** Auto-regressive reconstruction:
#  the plan is based on several assumptions that mr. <unk> and his team work on at least three interstate interstate interstate routes
# ** Original string:
#  the arco plan takes into account such details as which aspects of business are <unk> at certain times of the year
#
# 1 -- D = 7.15
# ** Auto-regressive reconstruction:
#  so far mr. <unk> and ms. bartlett's children report a story about the telephone ban banning <unk> and <unk> cigarettes
# ** Original string:
#  your oct. N front page noted that british lawyers have to wear <unk> in court and that these <unk> are made from horses'<unk>
#
# 2 -- D = 7.25
# ** Auto-regressive reconstruction:
#  <unk> and thomas mark report a final report is due tomorrow from the united states health services department
# ** Original string:
#  irs notice N describes this and other deadline relief for hugo's victims
#
# 3 -- D = 7.47
# ** Auto-regressive reconstruction:
#  there is a <unk> written in japan where some writers and directors talk about <unk> their future together and <unk>
# ** Original string:
#  here is a <unk> for ufo watchers complete with pictures of people who say they've had personal relationships with aliens
#
# 4 -- D = 7.57
# ** Auto-regressive reconstruction:
#  mr. <unk> said the experiment will be repeated in mice and possibly in humans before the new version will introduce a new drug to help treat retinob
# ** Original string:
#  mr. turner said the test initially will be used in <unk> with <unk> and other tests but eventually might become the benchmark for tumor analysis
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  he will discuss a list of poland's major <unk> industrial zones
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 7.61
# ** Auto-regressive reconstruction:
#  an alliance of u.s. and soviet designers sets out to win
# ** Original string:
#  an exchange of u.s. and soviet designers promises change on both sides
#
# 1 -- D = 7.72
# ** Auto-regressive reconstruction:
#  some analysts estimate the mine by N will begin exporting billions of dollars a year by year end
# ** Original string:
#  some projections show mexico importing crude by the end of the century barring an overhaul of operations
#
# 2 -- D = 7.73
# ** Auto-regressive reconstruction:
#  he was clear that neither the east bloc and the u.s. can translate into economic growth
# ** Original string:
#  his point was there is no reason for east germany to copy <unk> changes
#
# 3 -- D = 8.00
# ** Auto-regressive reconstruction:
#  the soviets nov. N would discuss imports of any products
# ** Original string:
#  no foreign companies bid on the hiroshima project according to the bureau
#
# 4 -- D = 8.07
# ** Auto-regressive reconstruction:
#  meanwhile the u.s. is studying what a <unk> scenario may be like next spring
# ** Original string:
#  says one west german official what's necessary now is the process of <unk>
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# ...
# ** Original string:
#  new environmentalism probably started in N with the publication of <unk> carson's book silent spring
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the new york trial is being prosecuted in new york by the national cancer institute in new york and in new york
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 6.57
# ** Auto-regressive reconstruction:
#  the study of the <unk> gene gene was inspired by the discovery of the <unk> gene in the <unk> gene gene in the early 1980s and is
# ** Original string:
#  the story of tumor-suppressor genes goes back to the 1970s when a <unk> named alfred g. <unk> jr. proposed that retinoblastoma stemmed from two separate genetic defects
#
# 1 -- D = 6.69
# ** Auto-regressive reconstruction:
#  mr. <unk> said the hospital is investigating the problem and is investigating the <unk> of <unk> in the san francisco area and the san francisco
# ** Original string:
#  dr. andrew <unk> city health director said his staff suspects the hepatitis which can be highly <unk> was spread by the cafeteria worker with the virus
#
# 2 -- D = 6.70
# ** Auto-regressive reconstruction:
#  the san francisco earthquake isn't known to have affected any other major earthquake in the u.s. but the san francisco earthquake association said
# ** Original string:
#  hepatitis a considered the least dangerous strain of the virus has been confirmed in at least one gte employee company and city officials said
#
# 3 -- D = 6.86
# ** Auto-regressive reconstruction:
#  the new york times editorial page has been a <unk> for the new york-based ad agency
# ** Original string:
#  christopher cox's oct. N editorial-page article toward more <unk> lawsuits misses the point
#
# 4 -- D = 6.86
# ** Auto-regressive reconstruction:
#  mr. <unk> was a pioneer in the genetics of the human immune system and was named to the prestigious journal of the immune system in N
# ** Original string:
#  dr. vogelstein next turned his attention to colon cancer the second biggest cancer killer in the u.s. after lung cancer
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the only thing i've seen is that the <unk> of the u.s. is not the only institution that is considered to be a good investment
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.63
# ** Auto-regressive reconstruction:
#  but it's hard to see why the dollar is so volatile because it isn't as volatile as the u.s. and european currencies
# ** Original string:
#  it's fair to say there are more risks for the pound under major than there were under lawson says malcolm roberts a director of international bond market research at salomon brothers in london
#
# 1 -- D = 5.71
# ** Auto-regressive reconstruction:
#  the junk bond market wasn't <unk> by the junk bond market which wasn't as active as the junk bond market in the past few weeks
# ** Original string:
#  according to a trader at drexel burnham lambert inc. the hardest hit junk bonds were those issued by rjr holdings capital corp. which are the <unk> to sell
#
# 2 -- D = 5.72
# ** Auto-regressive reconstruction:
#  the company said it isn't aware of any major new products in the pipeline but it is aware of several other products being developed by the company and that
# ** Original string:
#  there is strong indication that teddy z is not compatible with the shows it is surrounding said john <unk> senior vice president at j. walter thompson co. a unit of wpp group plc
#
# 3 -- D = 5.72
# ** Auto-regressive reconstruction:
#  the market isn't <unk> says <unk> <unk> a vice president at <unk> & <unk> a brokerage firm in new york and a market
# ** Original string:
#  it's not a very meaningful indicator currently because corporations are not <unk> in a traditional manner says james h. <unk> head of stock investments for cigna corp. the <unk> insurer
#
# 4 -- D = 5.73
# ** Auto-regressive reconstruction:
#  the market isn't going to be very attractive says <unk> <unk> a vice president at merrill lynch capital markets inc. in new york
# ** Original string:
#  even without a specific takeover threat courtaulds is giving shareholders choice and value said <unk> <unk> an analyst at london stockbrokers barclays de zoete wedd
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# Sample from prior decoded:
#  the <unk> index is based on the number of <unk> banks in the u.s. and europe
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 6.12
# ** Auto-regressive reconstruction:
#  the <unk> agency said the <unk> of the national association of financial institutions is the largest agency in the country
# ** Original string:
#  the <unk> newspaper publishes the withheld portion of the swedish national audit bureau's report
#
# 1 -- D = 6.15
# ** Auto-regressive reconstruction:
#  the bank of japan said it is considering <unk> its credit-card portfolio to attract new credit
# ** Original string:
#  bank of england governor robin <unk> urged banks to be cautious in financing leveraged buy-outs
#
# 2 -- D = 6.21
# ** Auto-regressive reconstruction:
#  the bank said it will continue to issue new debt and will continue to issue new subordinated debt to banks in the u.s. and europe
# ** Original string:
#  lloyd's of london said it plans to <unk> down on the ability of underwriting syndicates to leave their annual accounts open beyond the <unk> three years
#
# 3 -- D = 6.24
# ** Auto-regressive reconstruction:
#  mr. <unk> said the bank's recent move to <unk> the u.s. monetary policy to the u.s. economy is a sign
# ** Original string:
#  at a news conference this week bank of japan gov. <unk> <unk> cautioned banks to take a prudent stance regarding highly leveraged deals
#
# 4 -- D = 6.28
# ** Auto-regressive reconstruction:
#  mr. <unk> said the fed's <unk> of the u.s. economy is <unk>
# ** Original string:
#  new zealand's finance minister david <unk> <unk> out at such suggestions
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the <unk> of the world's most famous scientists are the <unk> of the world's <unk>
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.99
# ** Auto-regressive reconstruction:
#  the <unk> of the <unk> of the world is <unk> by the <unk> of the <unk>
# ** Original string:
#  critical opinion is divided about the success of benton's <unk> <unk> of <unk> art
#
# 1 -- D = 6.14
# ** Auto-regressive reconstruction:
#  the <unk> of the san francisco is a <unk> of the world of art
# ** Original string:
#  although set in japan the novel's <unk> is almost entirely western especially american
#
# 2 -- D = 6.18
# ** Auto-regressive reconstruction:
#  mr. <unk> and mr. <unk> have been <unk> in the past and have been <unk> by the press
# ** Original string:
#  mr. morishita <unk> at those stories as well as the ones connecting him to the japanese <unk>
#
# 3 -- D = 6.19
# ** Auto-regressive reconstruction:
#  the <unk> of the <unk> of the <unk> of the world is the <unk> of the <unk> of the world
# ** Original string:
#  the <unk> of his later work reflects both an appetite for new <unk> and the hazards of art in the arab world
#
# 4 -- D = 6.20
# ** Auto-regressive reconstruction:
#  the <unk> of the <unk> are often portrayed in <unk> and <unk> <unk> of the <unk> of the past century
# ** Original string:
#  but they do show the range of a <unk> <unk> whose <unk> novels span five decades and include work of social <unk> protest and <unk>
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the agency is investigating whether the toxin could cause serious problems in the plant's health
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 6.38
# ** Auto-regressive reconstruction:
#  the u.s. is considering a similar proposal to allow the u.s. to export its data to the u.s. from the u.
# ** Original string:
#  he said mexico could be one of the next countries to be removed from the priority list because of its efforts to craft a new patent law
#
# 1 -- D = 6.42
# ** Auto-regressive reconstruction:
#  the damage to the san francisco area is expected to be far greater than expected in the san francisco area
# ** Original string:
#  losses from the earthquake are expected to be of similar magnitude to those of hurricane hugo according to moody's
#
# 2 -- D = 6.46
# ** Auto-regressive reconstruction:
#  the company said it is reviewing the potential impact of the quake on the company's computer systems and other systems and is reviewing the possibility of a strike
# ** Original string:
#  among the issues the board will examine is whether united airlines a unit of ual corp. should have been able to detect the cracks through maintenance checks
#
# 3 -- D = 6.61
# ** Auto-regressive reconstruction:
#  the problem isn't new to the u.s. drug administration but is also being addressed
# ** Original string:
#  the delay in getting azt to children has been blamed on a combination of factors
#
# 4 -- D = 6.63
# ** Auto-regressive reconstruction:
#  the researchers say the treatment may be effective if it is taken early in the pregnancy and is followed by a second pregnancy test
# ** Original string:
#  but the test may prove to be more sensitive in determining whether a tumor has spread or returned following treatment dr. wilson said
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the first time the new version is available is in N is to be used in the <unk> of the year N
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 6.39
# ** Auto-regressive reconstruction:
#  the bill also would give the fed a more <unk> role in the reduction of the <unk> program and would allow the fed to increase its use of the
# ** Original string:
#  instead of proposing a complete elimination of farm subsidies as the earlier u.s. proposal did the new package calls for the elimination of only the most <unk> ones
#
# 1 -- D = 6.50
# ** Auto-regressive reconstruction:
#  the report also suggested that the industry's efforts to reduce the number of cars that were shipped last year weren't sufficient to offset the decline
# ** Original string:
#  a shift to producing more alcohol and less sugar had been expected but the latest news if true indicates a more drastic shift than had been anticipated
#
# 2 -- D = 6.58
# ** Auto-regressive reconstruction:
#  it isn't always <unk> for the first year of pregnancy because the first month of pregnancy is usually the most painful and the second is the most painful
# ** Original string:
#  it is most effective taken about a week after a woman misses her <unk> period up through the seventh week of pregnancy when it is <unk> less effective
#
# 3 -- D = 6.63
# ** Auto-regressive reconstruction:
#  the <unk> of the u.s. is about N N higher than the N N in the u.s. and is more likely to be grown
# ** Original string:
#  by N it will be planted more often than any other apple tree according to a recent survey of six <unk> <unk> by washington state university <unk> robert norton
#
# 4 -- D = 6.66
# ** Auto-regressive reconstruction:
#  but the number of people who are eligible for the assistance is far below the N N level in the 1970s
# ** Original string:
#  within a few years the outcome in most states is likely to be that abortion will be more restricted but not completely banned
#
# ------------------------------------------------------------
# ------------------------------------------------------------
#
# Sample from prior decoded:
#  the new breed is a <unk> of the <unk> of the world's largest magazine magazines
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.44
# ** Auto-regressive reconstruction:
#  the antibody is known as the <unk> toxin which causes the death of several of the human and <unk> of the human lung and the human <unk>
# ** Original string:
#  the reactions stem from the fact that the vaccine contains multiple copies of the whole <unk> pertussis bacterium which causes whooping cough
#
# 1 -- D = 5.49
# ** Auto-regressive reconstruction:
#  the <unk> of the two men are the most prominent of the two men who are considering a joint venture with the <unk> group
# ** Original string:
#  the issues are also thought to be important to the fcc's new chairman alfred <unk> a former am <unk> in his native missouri
#
# 2 -- D = 5.60
# ** Auto-regressive reconstruction:
#  the <unk> of the <unk> <unk> is a <unk> of the <unk> of the <unk> of the <unk>
# ** Original string:
#  the thief and the dogs is a <unk> work the first <unk> novel in <unk> but it is likely to <unk> western readers
#
# 3 -- D = 5.70
# ** Auto-regressive reconstruction:
#  the <unk> of the stock market is that it's a good fit for the <unk> and the <unk> of the <unk> who buy stocks
# ** Original string:
#  strong dividend growth he says is the black widow of valuation a reference to the female <unk> that attract males and then kill them after <unk>
#
# 4 -- D = 5.71
# ** Auto-regressive reconstruction:
#  the new product is a <unk> of the junk bond market that has been a major part of the junk-bond market
# ** Original string:
#  another interesting example is the poison pill adopted recently by <unk> national intergroup inc. a diversified holding company
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# Sample from prior decoded:
#  the <unk> of the national defense institute and the national defense institute of <unk> were the first to publish a <unk> of the world's most advanced
# ------------------------------------------------------------
# Means from train sample latents that lay closest:
# 0 -- D = 5.25
# ** Auto-regressive reconstruction:
#  the <unk> <unk> spacecraft was launched by the <unk> <unk> in <unk> mass. in N and was <unk> by the u.s.
# ** Original string:
#  the galileo spacecraft <unk> <unk> toward the planet jupiter while five <unk> aboard the space shuttle atlantis measured the earth's ozone layer
#
# 1 -- D = 5.48
# ** Auto-regressive reconstruction:
#  the <unk> <unk> of the <unk> <unk> of the world's top football players was the <unk> of the world's top football players
# ** Original string:
#  polls once named tokyo giants star <unk> <unk> a <unk> <unk> <unk> soul as the male symbol of japan
#
# 2 -- D = 5.56
# ** Auto-regressive reconstruction:
#  the <unk> computer system was in the <unk> of the space probe a computer that was <unk> to the space station in <unk>
# ** Original string:
#  the galileo worm apparently was <unk> on a computer in france <unk> up to nasa's space physics analysis network mr. redmond said
#
# 3 -- D = 5.58
# ** Auto-regressive reconstruction:
#  the <unk> computer was developed by a computer scientist in <unk> calif. and was used in a computer-guided <unk> program that was used in
# ** Original string:
#  the computer spy had discovered that a popular <unk> mail program called <unk> could do <unk> with the widely used unix operating system created by at&t
#
# 4 -- D = 5.67
# ** Auto-regressive reconstruction:
#  the computers were used to monitor the <unk> of the u.s. military and the u.s. intelligence agency and the <unk> of the u
# ** Original string:
#  the hacker was <unk> over the berkeley files but also using berkeley and other easily accessible computers as stepping stones to the network of computers used by the military and national security agencies
#
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
n_samples = 100
device_name = "cuda:0"

runs =  ["2021-02-03-PTB-latent32-FB-0.00-run-14:32:09",
 "2021-02-03-PTB-latent32-FB-0.5-run-09:31:02", 
 "2021-02-03-PTB-latent32-FB-1.0-run-11:43:17", 
 "2021-02-03-PTB-latent32-FB-1.50-run-12:13:36",
 "2021-02-03-PTB-latent32-autoencoder-run-17:30:41"]

text_preds = {}
atts_to_latent = {}

for r in runs:
    
    p = PTB_run_name_paths[r]
    print(get_clean_name(r))
    
    latent_size = int(r.split("-")[4][-2:])
    
    vae_model = load_model_for_eval(p, device_name="cuda:0", 
                                    latent_size=latent_size, 
                                    add_latent_via_memory=True,
                                    add_latent_via_embeddings=False, 
                                    do_tie_weights=True, 
                                    do_tie_embedding_spaces=True,
                                    add_decoder_output_embedding_bias=False)
    
    vae_model.eval()

    with torch.no_grad():
#         prior_sample = vae_model.sample_from_prior(latent_size, n_samples=n_samples, device_name=device_name)
        
        loc = torch.zeros(latent_size, device=device_name)
        scale = torch.ones(latent_size, device=device_name)*2.0
        prior_dist = torch.distributions.normal.Normal(loc, scale)
        prior_sample = prior_dist.sample((n_samples,))
        
        prior_sample = torch.zeros(latent_size, device=device_name)
        
        prior_decoded_ar = vae_model.decoder.autoregressive_decode(
                                                    prior_sample,
                                                    labels=None,
                                                    max_seq_len=32,
                                                    return_exact_match=False,
                                                    return_cross_entropy=False,
                                                    return_attention_probs=False,
                                                    return_attention_to_latent=True,
                                                    return_hidden_states=False,
                                                    return_last_hidden_state=False,
                                                    return_predictions=True,
                                                    return_probabilities=False,
                                                    return_output_word_embeddings=False,
                                                    return_logits=False,
                                                    tokenizer=tokenizer,
                                                    nucleus_sampling=False, # <-- to check variability from the latent turn this off
                                                    reduce_seq_dim_ce="sum",
                                                    reduce_seq_dim_exact_match="none",
                                                    reduce_batch_dim_exact_match="none",
                                                    reduce_batch_dim_ce="mean",
                                                    device_name=device_name)
        
        atts_to_latent[r] = prior_decoded_ar["attention_to_latent"].cpu()

        prior_decoded_ar_text = tokenizer_batch_decode(prior_decoded_ar["predictions"], tokenizer)
        ts = []
        for t in prior_decoded_ar_text:
            index_end = t.find("</s>")
            if index_end == -1:
                ts.append(t)
            else:
                ts.append(t[:index_end])
        text_preds[r] = ts

for (r, ts), (_, aw) in zip(text_preds.items(), atts_to_latent.items()):
    print("*"*40)
    print(get_clean_name(r))
    print("*"*40)
    # batch, n_heads, n_layers, seq_len_query, seq_len_val
    # attention_to_latent = attention_probs[:, :, :, :-1, 0]
    aw_mean_head_layers = aw.mean(dim=1).mean(dim=1)
#     print(aw_mean_head_layers.shape)
#     print(aw.shape)
    plt.imshow(aw_mean_head_layers.numpy())
    
    plt.title("Average attention to latent over sequence", y=1.05, size=12)
    plt.colorbar()
    plt.ylabel("Samples in batch")
    plt.xlabel("Sequence dimension")
    plt.show()
    for i, t in enumerate(ts):
        print(i, t)
        
    print("-"*30)
