# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../Data/all-the-news-2-1.csv', index_col=0, nrows=60000)

# %%
df.drop('Unnamed: 0.1', axis=1, inplace=True)
df.head()
# Out:
#                   date  year  month  day       author  \
# 0  2016-12-09 18:31:00  2016   12.0    9  Lee Drutman
# 1  2016-10-07 21:26:46  2016   10.0    7  Scott Davis
# 2  2018-01-26 00:00:00  2018    1.0   26          NaN
# 3  2019-06-27 00:00:00  2019    6.0   27          NaN
# 4  2016-01-27 00:00:00  2016    1.0   27          NaN
#
#                                                title  \
# 0  We should take concerns about the health of li...
# 1  Colts GM Ryan Grigson says Andrew Luck's contr...
# 2       Trump denies report he ordered Mueller fired
# 3  France's Sarkozy reveals his 'Passions' but in...
# 4  Paris Hilton: Woman In Black For Uncle Monty's...
#
#                                              article  \
# 0  This post is part of Polyarchy, an independent...
# 1   The Indianapolis Colts made Andrew Luck the h...
# 2  DAVOS, Switzerland (Reuters) - U.S. President ...
# 3  PARIS (Reuters) - Former French president Nico...
# ...

# %%
len(df.publication.value_counts())
# Out:
# 7

# %%
df.publication.value_counts().plot.bar()
plt.show()

# %%
lengths = []
for i, row in df.iterrows():
    if i < 100:
        print('\n\n')
        print(row.publication.upper(), '\t|\t', row.title.upper())
        print()
        print(row.article)
    if type(a) == str:
        lengths.append(len(a.split(' ')))
# Out:
# VOX 	|	 WE SHOULD TAKE CONCERNS ABOUT THE HEALTH OF LIBERAL DEMOCRACY SERIOUSLY
#
# ...

# %%
print("Average length and median lenght ((N=60K):", np.mean(lengths), np.median(lengths))
# Out:
# Average length and median lenght ((N=60K): 668.9561569191168 459.0

# %%
import matplotlib.pyplot as plt

plt.hist(lengths, bins=60)
plt.ylabel("Article frequency")
plt.xlabel("Number of words")
plt.title("Document lengths (N=60k)")
plt.show()

# %%
for i, row in enumerate(df.iterrows()):
    a = row.article
    
    if i < 100:
        
        print('\n\n--> NEW\n', a)
# Out:
# --> NEW
# ...

# %%
import numpy as np
np.mean(lengths)
# Out:
# 668.9561569191168
